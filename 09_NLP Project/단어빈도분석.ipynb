# %% [markdown]
# # 영화 줄거리 감성분석

# %%
import pandas as pd 
import numpy as np 
from tqdm import tqdm
from konlpy.tag import Okt
from collections import Counter
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./movie.csv')
df['내용'] = df['제목'] + " " + df['줄거리']
df
# Out:
#                                 제목    평점        감독  \
# 0                            범죄도시3   7.6       이상용
# 1     엘리멘탈(패키지: 자막판+더빙판+부가영상+코멘터리)   9.4      피터 손
# 2                       공조2: 인터내셔날   8.3       이석훈
# 3               아바타: 물의 길(부가영상 제공)   8.6   제임스 카메론
# 4                              올빼미   9.3       안태진
# ...                            ...   ...       ...
# 5191                    트론: 새로운 시작   7.3   조셉 코신스키
# 5192                리버티 벨런스를 쏜 사나이   8.4      존 포드
# 5193                         리썰 웨폰   8.3    리차드 도너
# 5194                     몽골리안 프린세스   7.5       정단우
# 5195            안녕자두야 스페셜 : 언더 더 씨  10.0       손석우
#
#                                                      배우  \
# 0          마동석 이준혁 아오키 무네타카 이범수 김민재 이지훈 김도건 고규필 전석호 안세호
# 1                                         레아 루이스 마무두 아티
# 2               현빈 유해진 윤아 다니엘 헤니 진선규 장영남 박훈 임성재 윤상화 박민하
# 3      조 샐다나 샘 워싱턴 시고니 위버 우나 채플린 지오바니 리비시 스티븐 랭 케이트 ...
# 4               류준열 유해진 최무성 조성하 박명훈 김성철 안은진 조윤서 이주원 김예은
# ...                                                 ...
# 5191   제프 브리지스 가렛 헤드룬드 올리비아 와일드 마이클 쉰 애니스 처파 브루스 박스라...
# 5192   존 웨인 제임스 스튜어트 베라 마일즈 리 마빈 에드먼드 오브라이언 앤디 데빈 켄 ...
# 5193               멜 깁슨 대니 글로버 게리 부시 미치 라이언 톰 앳킨스 달린 러브
# 5194                                 정단우 엘리자베스 가르시아 박하나
# 5195            여민정 양정화 정유미 김현지 최준영 정혜옥 김보영 김영은 정혜원 김새해
#
#                                                    개봉일자  \
# 0                                           2023.05.31.
# 1                                           2023.06.14.
# 2                                           2022.09.07.
# 3                                           2022.12.14.
# 4                                           2022.11.23.
# ...                                                 ...
# 5191                                        2010.12.29.
# 5192  주연 존 웨인 제임스 스튜어트 베라 마일즈 리 마빈 에드먼드 오브라이언 앤디 데빈 ...
# 5193                                        1987.12.01.
# 5194                                        2015.03.19.
# 5195         주연 여민정 양정화 정유미 김현지 최준영 정혜옥 김보영 김영은 정혜원 김새해
#
#                                                     줄거리  \
# 0     대체불가 괴물형사 마석도 서울 광수대로 발탁! 베트남 납치 살해범 검거 후 7년 뒤...
# 1     불 물 공기 흙 4개의 원소들이 살고 있는 ‘엘리멘트 시티’ 재치 있고 불처럼 열정...
# 2     공조 이즈 백! 이번엔 삼각 공조다!남한으로 숨어든 글로벌 범죄 조직을 잡기 위해 ...
# 3     <아바타: 물의 길>은 판도라 행성에서 '제이크 설리'와 '네이티리'가 이룬 가족이...
# 4     맹인이지만 뛰어난 침술 실력을 지닌 ‘경수’는어의 ‘이형익’에게 그 재주를 인정받아...
# ...                                                 ...
# 5191  세상 누구도 본적 없는 최고의 가상 현실을 창조한 천재박사 케빈 플린(제프 브리지스...
# 5192  랜스(제임스 스튜어트 분)는 자신의 오래전 친구 톰(존 웨인 분)의 장례식에 참석하...
# 5193  술집 여종업원인 아멘다 훤세커(Amanda Hunsaker: 잭키 스완슨 분)가 약...
# 5194  34살이 되도록 연애 한번 못해보고 영화밖에 모르고 살아온 ‘단우’. 어느 날 본인...
# 5195  안녕 자두야 스페셜 언더 더 씨! 바다에서 펼쳐지는 자두의 세가지 이야기. 하나 별...
#
#                                                      내용
# 0     범죄도시3 대체불가 괴물형사 마석도 서울 광수대로 발탁! 베트남 납치 살해범 검거 ...
# 1     엘리멘탈(패키지: 자막판+더빙판+부가영상+코멘터리) 불 물 공기 흙 4개의 원소들이...
# 2     공조2: 인터내셔날 공조 이즈 백! 이번엔 삼각 공조다!남한으로 숨어든 글로벌 범죄...
# 3     아바타: 물의 길(부가영상 제공) <아바타: 물의 길>은 판도라 행성에서 '제이크 ...
# 4     올빼미 맹인이지만 뛰어난 침술 실력을 지닌 ‘경수’는어의 ‘이형익’에게 그 재주를 ...
# ...                                                 ...
# 5191  트론: 새로운 시작 세상 누구도 본적 없는 최고의 가상 현실을 창조한 천재박사 케빈...
# 5192  리버티 벨런스를 쏜 사나이 랜스(제임스 스튜어트 분)는 자신의 오래전 친구 톰(존 ...
# 5193  리썰 웨폰 술집 여종업원인 아멘다 훤세커(Amanda Hunsaker: 잭키 스완슨...
# 5194  몽골리안 프린세스 34살이 되도록 연애 한번 못해보고 영화밖에 모르고 살아온 ‘단우...
# 5195  안녕자두야 스페셜 : 언더 더 씨 안녕 자두야 스페셜 언더 더 씨! 바다에서 펼쳐지...
#
# [5196 rows x 7 columns]

# %%
knu=pd.read_csv('../PYHTON/data/knu_sentiment_lexicon.csv')
knu
# Out:
#         word  polarity
# 0         ㅡㅡ        -1
# 1         ㅠㅠ        -1
# 2        ㅠ_ㅠ        -1
# 3          ㅠ        -1
# 4         ㅜㅡ        -1
# ...      ...       ...
# 14849  (^-^)         1
# 14850  (;_;)        -1
# 14851  (-_-)        -1
# 14852    (-;         1
# 14853   -_-^        -1
#
# [14854 rows x 2 columns]

# %%
okt = Okt()
senti = pd.read_csv("../PYHTON/data/knu_sentiment_lexicon.csv") # 감성사전
total_score = []


for i in tqdm(df['내용']):
    t = okt.normalize(str(i))
    score = 0
    
    for w, p in zip(senti['word'], senti['polarity']):
        score += t.count(w) * p 
    total_score.append(score)

df['감성점수'] = total_score
df
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 5196/5196 [05:00<00:00, 17.32it/s]
#                                 제목    평점        감독  \
# 0                            범죄도시3   7.6       이상용
# 1     엘리멘탈(패키지: 자막판+더빙판+부가영상+코멘터리)   9.4      피터 손
# 2                       공조2: 인터내셔날   8.3       이석훈
# 3               아바타: 물의 길(부가영상 제공)   8.6   제임스 카메론
# 4                              올빼미   9.3       안태진
# ...                            ...   ...       ...
# 5191                    트론: 새로운 시작   7.3   조셉 코신스키
# 5192                리버티 벨런스를 쏜 사나이   8.4      존 포드
# 5193                         리썰 웨폰   8.3    리차드 도너
# 5194                     몽골리안 프린세스   7.5       정단우
# 5195            안녕자두야 스페셜 : 언더 더 씨  10.0       손석우
#
#                                                      배우  \
# 0          마동석 이준혁 아오키 무네타카 이범수 김민재 이지훈 김도건 고규필 전석호 안세호
# 1                                         레아 루이스 마무두 아티
# 2               현빈 유해진 윤아 다니엘 헤니 진선규 장영남 박훈 임성재 윤상화 박민하
# 3      조 샐다나 샘 워싱턴 시고니 위버 우나 채플린 지오바니 리비시 스티븐 랭 케이트 ...
# 4               류준열 유해진 최무성 조성하 박명훈 김성철 안은진 조윤서 이주원 김예은
# ...                                                 ...
# 5191   제프 브리지스 가렛 헤드룬드 올리비아 와일드 마이클 쉰 애니스 처파 브루스 박스라...
# 5192   존 웨인 제임스 스튜어트 베라 마일즈 리 마빈 에드먼드 오브라이언 앤디 데빈 켄 ...
# 5193               멜 깁슨 대니 글로버 게리 부시 미치 라이언 톰 앳킨스 달린 러브
# 5194                                 정단우 엘리자베스 가르시아 박하나
# 5195            여민정 양정화 정유미 김현지 최준영 정혜옥 김보영 김영은 정혜원 김새해
#
#                                                    개봉일자  \
# 0                                           2023.05.31.
# 1                                           2023.06.14.
# 2                                           2022.09.07.
# 3                                           2022.12.14.
# 4                                           2022.11.23.
# ...                                                 ...
# 5191                                        2010.12.29.
# 5192  주연 존 웨인 제임스 스튜어트 베라 마일즈 리 마빈 에드먼드 오브라이언 앤디 데빈 ...
# 5193                                        1987.12.01.
# 5194                                        2015.03.19.
# 5195         주연 여민정 양정화 정유미 김현지 최준영 정혜옥 김보영 김영은 정혜원 김새해
#
#                                                     줄거리  \
# 0     대체불가 괴물형사 마석도 서울 광수대로 발탁! 베트남 납치 살해범 검거 후 7년 뒤...
# 1     불 물 공기 흙 4개의 원소들이 살고 있는 ‘엘리멘트 시티’ 재치 있고 불처럼 열정...
# 2     공조 이즈 백! 이번엔 삼각 공조다!남한으로 숨어든 글로벌 범죄 조직을 잡기 위해 ...
# 3     <아바타: 물의 길>은 판도라 행성에서 '제이크 설리'와 '네이티리'가 이룬 가족이...
# 4     맹인이지만 뛰어난 침술 실력을 지닌 ‘경수’는어의 ‘이형익’에게 그 재주를 인정받아...
# ...                                                 ...
# 5191  세상 누구도 본적 없는 최고의 가상 현실을 창조한 천재박사 케빈 플린(제프 브리지스...
# 5192  랜스(제임스 스튜어트 분)는 자신의 오래전 친구 톰(존 웨인 분)의 장례식에 참석하...
# 5193  술집 여종업원인 아멘다 훤세커(Amanda Hunsaker: 잭키 스완슨 분)가 약...
# 5194  34살이 되도록 연애 한번 못해보고 영화밖에 모르고 살아온 ‘단우’. 어느 날 본인...
# 5195  안녕 자두야 스페셜 언더 더 씨! 바다에서 펼쳐지는 자두의 세가지 이야기. 하나 별...
#
#                                                      내용  감성점수
# 0     범죄도시3 대체불가 괴물형사 마석도 서울 광수대로 발탁! 베트남 납치 살해범 검거 ...   -14
# 1     엘리멘탈(패키지: 자막판+더빙판+부가영상+코멘터리) 불 물 공기 흙 4개의 원소들이...     9
# 2     공조2: 인터내셔날 공조 이즈 백! 이번엔 삼각 공조다!남한으로 숨어든 글로벌 범죄...   -19
# 3     아바타: 물의 길(부가영상 제공) <아바타: 물의 길>은 판도라 행성에서 '제이크 ...    -5
# 4     올빼미 맹인이지만 뛰어난 침술 실력을 지닌 ‘경수’는어의 ‘이형익’에게 그 재주를 ...   -12
# ...                                                 ...   ...
# 5191  트론: 새로운 시작 세상 누구도 본적 없는 최고의 가상 현실을 창조한 천재박사 케빈...     9
# 5192  리버티 벨런스를 쏜 사나이 랜스(제임스 스튜어트 분)는 자신의 오래전 친구 톰(존 ...    -8
# 5193  리썰 웨폰 술집 여종업원인 아멘다 훤세커(Amanda Hunsaker: 잭키 스완슨...   -24
# 5194  몽골리안 프린세스 34살이 되도록 연애 한번 못해보고 영화밖에 모르고 살아온 ‘단우...    -8
# 5195  안녕자두야 스페셜 : 언더 더 씨 안녕 자두야 스페셜 언더 더 씨! 바다에서 펼쳐지...     2
#
# [5196 rows x 8 columns]

# %%
senti_score=[]
for score in df['감성점수']:
    if score>0 : senti_score.append('긍정')
    elif score<0 : senti_score.append('부정')
    else : senti_score.append('중립')

# %%
df['감성분석결과']=senti_score
df
# Out:
#                                 제목    평점        감독  \
# 0                            범죄도시3   7.6       이상용
# 1     엘리멘탈(패키지: 자막판+더빙판+부가영상+코멘터리)   9.4      피터 손
# 2                       공조2: 인터내셔날   8.3       이석훈
# 3               아바타: 물의 길(부가영상 제공)   8.6   제임스 카메론
# 4                              올빼미   9.3       안태진
# ...                            ...   ...       ...
# 5191                    트론: 새로운 시작   7.3   조셉 코신스키
# 5192                리버티 벨런스를 쏜 사나이   8.4      존 포드
# 5193                         리썰 웨폰   8.3    리차드 도너
# 5194                     몽골리안 프린세스   7.5       정단우
# 5195            안녕자두야 스페셜 : 언더 더 씨  10.0       손석우
#
#                                                      배우  \
# 0          마동석 이준혁 아오키 무네타카 이범수 김민재 이지훈 김도건 고규필 전석호 안세호
# 1                                         레아 루이스 마무두 아티
# 2               현빈 유해진 윤아 다니엘 헤니 진선규 장영남 박훈 임성재 윤상화 박민하
# 3      조 샐다나 샘 워싱턴 시고니 위버 우나 채플린 지오바니 리비시 스티븐 랭 케이트 ...
# 4               류준열 유해진 최무성 조성하 박명훈 김성철 안은진 조윤서 이주원 김예은
# ...                                                 ...
# 5191   제프 브리지스 가렛 헤드룬드 올리비아 와일드 마이클 쉰 애니스 처파 브루스 박스라...
# 5192   존 웨인 제임스 스튜어트 베라 마일즈 리 마빈 에드먼드 오브라이언 앤디 데빈 켄 ...
# 5193               멜 깁슨 대니 글로버 게리 부시 미치 라이언 톰 앳킨스 달린 러브
# 5194                                 정단우 엘리자베스 가르시아 박하나
# 5195            여민정 양정화 정유미 김현지 최준영 정혜옥 김보영 김영은 정혜원 김새해
#
#                                                    개봉일자  \
# 0                                           2023.05.31.
# 1                                           2023.06.14.
# 2                                           2022.09.07.
# 3                                           2022.12.14.
# 4                                           2022.11.23.
# ...                                                 ...
# 5191                                        2010.12.29.
# 5192  주연 존 웨인 제임스 스튜어트 베라 마일즈 리 마빈 에드먼드 오브라이언 앤디 데빈 ...
# 5193                                        1987.12.01.
# 5194                                        2015.03.19.
# 5195         주연 여민정 양정화 정유미 김현지 최준영 정혜옥 김보영 김영은 정혜원 김새해
#
#                                                     줄거리  \
# 0     대체불가 괴물형사 마석도 서울 광수대로 발탁! 베트남 납치 살해범 검거 후 7년 뒤...
# 1     불 물 공기 흙 4개의 원소들이 살고 있는 ‘엘리멘트 시티’ 재치 있고 불처럼 열정...
# 2     공조 이즈 백! 이번엔 삼각 공조다!남한으로 숨어든 글로벌 범죄 조직을 잡기 위해 ...
# 3     <아바타: 물의 길>은 판도라 행성에서 '제이크 설리'와 '네이티리'가 이룬 가족이...
# 4     맹인이지만 뛰어난 침술 실력을 지닌 ‘경수’는어의 ‘이형익’에게 그 재주를 인정받아...
# ...                                                 ...
# 5191  세상 누구도 본적 없는 최고의 가상 현실을 창조한 천재박사 케빈 플린(제프 브리지스...
# 5192  랜스(제임스 스튜어트 분)는 자신의 오래전 친구 톰(존 웨인 분)의 장례식에 참석하...
# 5193  술집 여종업원인 아멘다 훤세커(Amanda Hunsaker: 잭키 스완슨 분)가 약...
# 5194  34살이 되도록 연애 한번 못해보고 영화밖에 모르고 살아온 ‘단우’. 어느 날 본인...
# 5195  안녕 자두야 스페셜 언더 더 씨! 바다에서 펼쳐지는 자두의 세가지 이야기. 하나 별...
#
#                                                      내용  감성점수 감성분석결과
# 0     범죄도시3 대체불가 괴물형사 마석도 서울 광수대로 발탁! 베트남 납치 살해범 검거 ...   -14     부정
# 1     엘리멘탈(패키지: 자막판+더빙판+부가영상+코멘터리) 불 물 공기 흙 4개의 원소들이...     9     긍정
# 2     공조2: 인터내셔날 공조 이즈 백! 이번엔 삼각 공조다!남한으로 숨어든 글로벌 범죄...   -19     부정
# 3     아바타: 물의 길(부가영상 제공) <아바타: 물의 길>은 판도라 행성에서 '제이크 ...    -5     부정
# 4     올빼미 맹인이지만 뛰어난 침술 실력을 지닌 ‘경수’는어의 ‘이형익’에게 그 재주를 ...   -12     부정
# ...                                                 ...   ...    ...
# 5191  트론: 새로운 시작 세상 누구도 본적 없는 최고의 가상 현실을 창조한 천재박사 케빈...     9     긍정
# 5192  리버티 벨런스를 쏜 사나이 랜스(제임스 스튜어트 분)는 자신의 오래전 친구 톰(존 ...    -8     부정
# 5193  리썰 웨폰 술집 여종업원인 아멘다 훤세커(Amanda Hunsaker: 잭키 스완슨...   -24     부정
# 5194  몽골리안 프린세스 34살이 되도록 연애 한번 못해보고 영화밖에 모르고 살아온 ‘단우...    -8     부정
# 5195  안녕자두야 스페셜 : 언더 더 씨 안녕 자두야 스페셜 언더 더 씨! 바다에서 펼쳐지...     2     긍정
#
# [5196 rows x 9 columns]

# %%
import seaborn as sns
import koreanize_matplotlib

sns.countplot(data=df, x='감성분석결과')
# Out:
# <Axes: xlabel='감성분석결과', ylabel='count'>

# %%
total=[]

drop_ = ['위해','이야기','해리','안나','선화','사라','한편','이제','과연','대한','점점','이자','다시']
for a in tqdm(df['내용']):
    box = []
    for i in okt.nouns(a):
        if len(i)>1: 
            if i not in drop_ : box.append(i)
    total.append(box)
total
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 5195/5195 [01:59<00:00, 43.56it/s]
# [['범죄',
#   '도시',
#   '대체',
#   '불가',
#   '괴물',
#   '형사',
#   '석도',
#   '서울',
#   '광수',
#   '발탁',
#   '베트남',
#   '납치',
#   '살해',
#   '검거',
#   '석도',
#   '마동석',
#   '팀원',
#   '살인',
#   '사건',
#   '조사',
#   '사건',
#   '조사',
#   '석도',
#   '신종',
#   '마약',
#   '사건',
#   '연루',
#   '수사',
#   '확대',
#   '마약',
#   '사건',
#   '배후',
#   '주성철',
#   '이준혁',
#   '계속',
#   '유통',
#   '일본',
#   '조직',
#   '리키',
#   '아오키',
#   '타카',
#   '한국',
#   '사건',
#   '규모',
#   '이유',
#   '제한',
#   '판도'],
#  ['엘리',
#   '멘탈',
#   '패키지',
#   '자막',
#   '더빙',
#   '부가',
#   '영상',
#   '터리',
#   '공기',
#   '원소',
#   '엘리',
#   '멘트',
#   '시티',
#   '재치',
#   '열정',
#   '앰버',
#   '감성',
#   '이드',
#   '우정',
#   '지금껏',
#   '모든',
#   '경험',
#   '웰컴',
#   '엘리',
#   '멘트',
#   '시티'],
#  ['공조',
#   '인터',
#   '공조',
#   '이즈',
#   '이번',
#   '삼각',
#   '공조',
#   '남한',
#   '글로벌',
#   '범죄',
#   '조직',
#   '잡기',
#   '공조',
#   '수사',
#   '투입',
#   '북한',
#   '형사',
#   '철령',
#   '현빈',
#   '수사',
#   '실수',
#   '사이버수사대',
#   '전출',
#   '남한',
#   '형사',
#   '진태',
#   '유해진',
#   '광수',
#   '복귀',
#   '모두',
#   '기피',
#   '철령',
#   '파트너',
#   '자청',
#   '공조',
#   '철령',
#   '진태',
#   '철령',
#   '재회',
#   '민영',
#   '임윤아',
#   '마음',
#   '불타',
#   '가운데',
#   '철령',
#   '진태',
#   '서로',
#   '의심',
#   '나름',
#   '공조',
#   '수사',
#   '범죄',
#   '조직',
#   '리더',
#   '진선규',
#   '은신',
#   '찰나',
#   '미국',
#   '소속',
#   '다니엘',
#   '남한',
#   '형사',
#   '엘리트',
#   '북한',
#   '형사',
#   '소속',
#   '해외',
#   '형사',
#   '각자',
#   '목적',
#   '공조',
#   '수사',
#   '시작'],
#  ['아바타',
#   '물의',
#   '부가',
#   '영상',
#   '제공',
#   '아바타',
#   '물의',
#   '판도라',
#   '행성',
#   '제이크',
#   '설리',
#   '네이티',
#   '가족',
#   '위협',
#   '여정',
#   '전투',
#   '상처',
#   '월드',
#   '와이드',
#   '역대',
#   '흥행',
#   '순위',
#   '기록',
#   '전편',
#   '아바타',
#   '제임스',
#   '카메론',
#   '감독',
#   '영화로',
#   '워싱턴',
#   '고니',
#   '위버',
#   '스티븐',
#   '케이트',
#   '윈슬렛',
#   '출연',
#   '랜도',
#   '프로듀싱'],
#  ['올빼미',
#   '맹인',
#   '침술',
#   '실력',
#   '경수',
#   '이형',
#   '재주',
#   '무렵',
#   '인질',
#   '소현세자',
#   '귀국',
#   '인조',
#   '아들',
#   '잠시',
#   '정체',
#   '불안감',
#   '어둠',
#   '경수',
#   '소현세자',
#   '죽음',
#   '목격',
#   '찰나',
#   '비밀',
#   '음모',
#   '목숨',
#   '위태',
#   '상황',
#   '아들',
#   '죽음',
#   '인조',
#   '불안감',
#   '광기',
#   '폭주',
#   '시작',
#   '세자',
#   '죽음',
#   '목격',
#   '경수',
#   '관련',
#   '인물',
#   '민낯',
#   '서서히'],
#  ['범죄',
#   '도시',
#   '가리봉동',
#   '소탕',
#   '작전',
#   '금천',
#   '강력반',
#   '베트남',
#   '도주',
#   '용의자',
#   '인도',
#   '오라',
#   '미션',
#   '괴물',
#   '형사',
#   '석도',
#   '마동석',
#   '전일',
#   '귀화',
#   '반장',
#   '현지',
#   '용의자',
#   '악행',
#   '해상',
#   '석도',
#   '금천',
#   '강력반',
#   '한국',
#   '베트남',
#   '역대',
#   '범죄',
#   '해상',
#   '본격',
#   '시작',
#   '국경',
#   '범죄',
#   '소탕',
#   '작전'],
#  ['에브리씽',
#   '에브리',
#   '웨어',
#   '원스',
#   '미국',
#   '이민',
#   '세탁소',
#   '운영',
#   '에블린',
#   '세무',
#   '당국',
#   '조사',
#   '남편',
#   '이혼',
#   '요구',
#   '혼란',
#   '순간',
#   '에블린',
#   '멀티버스',
#   '수천',
#   '수만',
#   '자신',
#   '세상',
#   '사실',
#   '모든',
#   '능력',
#   '위기',
#   '세상',
#   '가족',
#   '구해',
#   '운명'],
#  ['아바타',
#   '마스터링',
#   '미래',
#   '지구',
#   '에너지',
#   '고갈',
#   '문제',
#   '해결',
#   '행성',
#   '판도라',
#   '대체',
#   '자원',
#   '채굴',
#   '시작',
#   '판도라',
#   '독성',
#   '대기',
#   '자원',
#   '획득',
#   '어려움',
#   '인류',
#   '판도라',
#   '토착민',
#   '나비',
#   '외형',
#   '인간',
#   '의식',
#   '주입',
#   '원격',
#   '조종',
#   '생명체',
#   '아바타',
#   '탄생',
#   '프로그램',
#   '개발',
#   '하반신',
#   '마비',
#   '전직',
#   '해병대',
#   '제이크',
#   '설리',
#   '워딩튼',
#   '아바타',
#   '프로그램',
#   '참가',
#   '제안',
#   '판도라',
#   '위치',
#   '인간',
#   '주둔',
#   '기지',
#   '자신',
#   '아바타',
#   '통해',
#   '제이크',
#   '자원',
#   '채굴',
#   '나비',
#   '무리',
#   '침투',
#   '임무',
#   '부여',
#   '임무',
#   '수행',
#   '나비',
#   '전사',
#   '네이티',
#   '만난',
#   '제이크',
#   '그녀',
#   '모험',
#   '경험',
#   '네이티',
#   '사랑',
#   '나비',
#   '하나',
#   '간다',
#   '우주',
#   '운명',
#   '결정',
#   '대규모',
#   '전투',
#   '시작',
#   '제이크',
#   '최후',
#   '시험대',
#   '행성',
#   '판도라',
#   '지구',
#   '전쟁',
#   '모든',
#   '운명',
#   '제이크',
#   '선택'],
#  ['화이트',
#   '릴리',
#   '주인공',
#   '하루',
#   '아스카',
#   '시절',
#   '자신',
#   '도예',
#   '토키',
#   '야마구치',
#   '카오리',
#   '스승',
#   '모시',
#   '그녀',
#   '토키',
#   '주변',
#   '남성',
#   '관계',
#   '하루',
#   '성적',
#   '요구',
#   '자신',
#   '욕망',
#   '하루',
#   '그녀',
#   '진심',
#   '사랑',
#   '남성',
#   '사토',
#   '마치',
#   '우마',
#   '조수',
#   '그로',
#   '하루',
#   '점차',
#   '스승',
#   '욕망',
#   '시작',
#   '토키',
#   '하루',
#   '충격',
#   '명령'],
#  ['슈퍼',
#   '마리오',
#   '브라더스',
#   '패키지',
#   '자막',
#   '더빙',
#   '세계',
#   '열광',
#   '타임',
#   '슈퍼',
#   '어드벤처',
#   '등장',
#   '뉴욕',
#   '배관',
#   '형제',
#   '마리오',
#   '루이지',
#   '배수관',
#   '고장',
#   '위기',
#   '도시',
#   '미스터리',
#   '초록색',
#   '파이프',
#   '파이프',
#   '통해',
#   '세상',
#   '차원',
#   '이동',
#   '형제',
#   '마리오',
#   '리더십',
#   '피치',
#   '통치',
#   '버섯',
#   '왕국',
#   '도착',
#   '동생',
#   '루이지',
#   '빌런',
#   '쿠파',
#   '다크랜드',
#   '납치',
#   '마리오',
#   '동생',
#   '피치',
#   '키노피오',
#   '도움',
#   '쿠파',
#   '결심',
#   '슈퍼스타',
#   '세상',
#   '지배',
#   '위험',
#   '동생',
#   '세상',
#   '슈퍼',
#   '마리오',
#   '레벨',
#   '마리오',
#   '스펙',
#   '스테이지',
#   '시작'],
#  ['위기',
#   '최고',
#   '회의',
#   '트릴',
#   '방법',
#   '비로소',
#   '자유',
#   '희망',
#   '보지',
#   '빌런',
#   '그라몽',
#   '후작',
#   '세계',
#   '최강',
#   '연합',
#   '친구',
#   '위기',
#   '최후',
#   '반격',
#   '준비',
#   '레전드',
#   '액션',
#   '블록버스터',
#   '린다'],
#  ['랍스터',
#   '대미',
#   '문의',
#   '커플',
#   '메이킹',
#   '호텔',
#   '사랑',
#   '모두',
#   '유죄',
#   '유예',
#   '기간',
#   '동물',
#   '미래',
#   '모든',
#   '사람',
#   '서로',
#   '홀로',
#   '커플',
#   '메이킹',
#   '호텔',
#   '커플',
#   '교육',
#   '불구',
#   '얻지',
#   '사람',
#   '동물',
#   '이유',
#   '아내',
#   '호텔',
#   '데이비드',
#   '콜린',
#   '파렐',
#   '찾기',
#   '노력',
#   '커플',
#   '거부',
#   '혼자',
#   '선택',
#   '솔로',
#   '솔로',
#   '생활',
#   '유지',
#   '절대',
#   '규칙',
#   '바로',
#   '절대',
#   '사랑',
#   '아이러니',
#   '데이비드',
#   '사랑',
#   '허락',
#   '자신',
#   '근시',
#   '레이첼',
#   '와이즈'],
#  ['이름',
#   '도시',
#   '소년',
#   '타키',
#   '시골',
#   '소녀',
#   '미츠하',
#   '만난',
#   '사람',
#   '기적',
#   '사랑',
#   '이름',
#   '사람',
#   '사람',
#   '이름'],
#  ['남자',
#   '은밀',
#   '성인',
#   '클럽',
#   '쇼걸',
#   '나탈리',
#   '그녀',
#   '동경',
#   '바텐더',
#   '상드',
#   '클럽',
#   '해고',
#   '상드',
#   '나탈리',
#   '제안',
#   '그녀',
#   '동거',
#   '시작',
#   '나탈리',
#   '상드',
#   '성적',
#   '욕망',
#   '남자',
#   '성적',
#   '지배',
#   '하나',
#   '하나',
#   '간다',
#   '나탈리',
#   '쾌락',
#   '욕망',
#   '깨달',
#   '상드',
#   '그녀',
#   '자신',
#   '미모',
#   '이용',
#   '상류층',
#   '계획',
#   '화이트',
#   '칼라',
#   '남자',
#   '접근',
#   '절대',
#   '사랑',
#   '원칙',
#   '대기업',
#   '비서',
#   '취직',
#   '상드',
#   '나탈리',
#   '각자',
#   '유혹',
#   '대상',
#   '정해',
#   '본격',
#   '작업',
#   '상드',
#   '유혹',
#   '대상',
#   '회사',
#   '중역',
#   '중년',
#   '라크',
#   '사무실',
#   '은밀',
#   '섹스',
#   '회사',
#   '후계',
#   '크리스토퍼',
#   '문제',
#   '장면',
#   '크리스토퍼',
#   '상드',
#   '더욱',
#   '은밀',
#   '게임',
#   '제안',
#   '바람둥이',
#   '온갖',
#   '섹스',
#   '행위',
#   '크리스토퍼',
#   '게임',
#   '그녀',
#   '승리'],
#  ['블랙',
#   '아담',
#   '부가',
#   '영상',
#   '제공',
#   '기원전',
#   '가장',
#   '번성',
#   '고대',
#   '국가',
#   '현재',
#   '국제',
#   '군사',
#   '조직',
#   '인터',
#   '독재',
#   '국가',
#   '전락',
#   '다크',
#   '인터',
#   '피해',
#   '고대',
#   '유물',
#   '동안',
#   '블랙',
#   '아담',
#   '괴력',
#   '스피드',
#   '방탄',
#   '능력',
#   '자유자',
#   '재의',
#   '고공',
#   '비행',
#   '번개',
#   '능력',
#   '온몸',
#   '무기',
#   '블랙',
#   '아담',
#   '자신',
#   '인터',
#   '모조리',
#   '다크',
#   '국민',
#   '폭주',
#   '호크',
#   '닥터',
#   '페이트',
#   '아톰',
#   '스매셔',
#   '사이클론',
#   '구성',
#   '히어로',
#   '군단',
#   '저스티스',
#   '소사이어티',
#   '다크',
#   '세상',
#   '파괴',
#   '사람',
#   '문제',
#   '히어로'],
#  ['파라벨룸',
#   '전설',
#   '킬러',
#   '아누',
#   '리브',
#   '현상금',
#   '세계',
#   '모든',
#   '킬러',
#   '총구',
#   '국제',
#   '암살자',
#   '연맹',
#   '파문',
#   '조치',
#   '보호',
#   '시시각각',
#   '위험',
#   '직면',
#   '마지막',
#   '전쟁',
#   '소피아',
#   '할리',
#   '베리',
#   '출구',
#   '평화',
#   '전쟁',
#   '준비',
#   '하라'],
#  ['영웅',
#   '어머니',
#   '조마리아',
#   '나문희',
#   '가족',
#   '고향',
#   '대한제국',
#   '의병',
#   '대장',
#   '안중근',
#   '정성화',
#   '동지',
#   '손가락',
#   '단지',
#   '동맹',
#   '조국',
#   '독립',
#   '결의',
#   '안중근',
#   '조선',
#   '침략',
#   '원흉',
#   '이토',
#   '히로',
#   '처단',
#   '자결',
#   '피로',
#   '맹세',
#   '약속',
#   '블라디보스토크',
#   '안중근',
#   '동지',
#   '우덕순',
#   '조재윤',
#   '사수',
#   '도선',
#   '배정남',
#   '독립군',
#   '막내',
#   '유동',
#   '이현우',
#   '독립군',
#   '동지',
#   '진주',
#   '박진주',
#   '거사',
#   '준비',
#   '자신',
#   '정체',
#   '이토',
#   '히로',
#   '접근',
#   '적진',
#   '복판',
#   '목숨',
#   '정보',
#   '수집',
#   '독립군',
#   '정보원',
#   '김고은',
#   '이토',
#   '히로',
#   '미가',
#   '러시아',
#   '회담',
#   '하얼빈',
#   '일급',
#   '기밀',
#   '안중근',
#   '하얼빈역',
#   '도착',
#   '이토',
#   '히로',
#   '주저',
#   '방아쇠',
#   '현장',
#   '체포',
#   '전쟁',
#   '포로',
#   '살인',
#   '죄목',
#   '조선',
#   '일본',
#   '법정',
#   '누가',
#   '죄인',
#   '누가',
#   '영웅'],
#  ['비포',
#   '미드나잇',
#   '시작',
#   '사랑',
#   '비엔나',
#   '기차',
#   '파리',
#   '재회',
#   '제시',
#   '셀린느',
#   '지금',
#   '사람',
#   '사랑',
#   '시작',
#   '우리',
#   '사랑',
#   '시작',
#   '그리스',
#   '해변',
#   '마을',
#   '카르',
#   '밀리',
#   '매일',
#   '화해',
#   '지난',
#   '사랑',
#   '계속',
#   '간다',
#   '우리',
#   '사랑',
#   '비포',
#   '시리즈',
#   '마지막'],
#  ['가디언즈',
#   '오브',
#   '갤럭시',
#   '세트',
#   '가모라',
#   '슬픔',
#   '피터',
#   '위기',
#   '은하계',
#   '동료',
#   '한번',
#   '가디언즈',
#   '경우',
#   '마지막',
#   '미션'],
#  ['하몽',
#   '하몽',
#   '실비',
#   '로프',
#   '크루즈',
#   '고속도로',
#   '매춘',
#   '술집',
#   '운영',
#   '카르멘',
#   '칼리',
#   '조카',
#   '국내',
#   '번역',
#   '조카',
#   '실제',
#   '설정',
#   '어머니',
#   '팬티',
#   '회사',
#   '공장',
#   '관능',
#   '처녀',
#   '실비',
#   '팬티',
#   '공장',
#   '사장',
#   '아들',
#   '호세',
#   '조디',
#   '연인',
#   '사이',
#   '호세',
#   '어머니',
#   '콘치',
#   '스테파니',
#   '샌드렐리',
#   '반대',
#   '사람',
#   '창녀',
#   '조카',
#   '신분',
#   '이유',
#   '호세',
#   '아버지',
#   '마뉴',
#   '후안',
#   '디에고',
#   '카르멘',
#   '불륜',
#   '관계',
#   '사실',
#   '때문',
#   '호세',
#   '비아',
#   '결혼',
#   '승락',
#   '하자',
#   '사람',
#   '사이',
#   '작심',
#   '콘치',
#   '건조',
#   '공장',
#   '투우사',
#   '지망',
#   '라울',
#   '하비에르',
#   '바르뎀',
#   '고용',
#   '비아',
#   '유혹',
#   '주문',
#   '과정',
#   '라울',
#   '육체',
#   '콘치',
#   '라울',
#   '불륜',
#   '행각',
#   '벌이',
#   '라울',
#   '접근',
#   '마음',
#   '시작',
#   '실비',
#   '때문',
#   '번뇌',
#   '호세',
#   '카르멘',
#   '육체',
#   '관계',
#   '비아',
#   '관계',
#   '라울',
#   '콘치',
#   '정사',
#   '장면',
#   '목격',
#   '이성',
#   '호세',
#   '라울',
#   '결심',
#   '건조',
#   '공장',
#   '라울',
#   '결투',
#   '벌이',
#   '오히려',
#   '라울',
#   '건조장',
#   '실비',
#   '카르멘',
#   '마뉴',
#   '통한',
#   '눈물'],
#  ['헌트',
#   '낯선',
#   '사람',
#   '의문',
#   '지역',
#   '영문',
#   '사냥',
#   '크리스탈',
#   '베티',
#   '길핀',
#   '자신',
#   '사냥',
#   '주체',
#   '복수',
#   '투하'],
#  ['던전',
#   '드래곤',
#   '도적',
#   '명예',
#   '명예',
#   '기사',
#   '사건',
#   '이후',
#   '사이먼',
#   '포지',
#   '도적',
#   '에드',
#   '피나',
#   '제안',
#   '부활',
#   '잠입',
#   '포지',
#   '피나',
#   '배신',
#   '감옥',
#   '방법',
#   '탈옥',
#   '에드',
#   '사람',
#   '부활',
#   '자신',
#   '시작',
#   '동료',
#   '소질',
#   '사이먼',
#   '합류',
#   '변신',
#   '천재',
#   '드루이드',
#   '도릭',
#   '재미',
#   '팔라딘',
#   '어딘가',
#   '오합지졸',
#   '모험',
#   '가디언즈',
#   '오브',
#   '갤럭시',
#   '어벤져스',
#   '에이지',
#   '오브',
#   '트론',
#   '매력',
#   '만점',
#   '롤플레잉',
#   '액션',
#   '어드벤처',
#   '무비'],
#  ['가디언즈',
#   '오브',
#   '갤럭시',
#   '부가',
#   '영상',
#   '터리',
#   '제공',
#   '가모라',
#   '슬픔',
#   '피터',
#   '위기',
#   '은하계',
#   '동료',
#   '한번',
#   '가디언즈',
#   '경우',
#   '마지막',
#   '미션'],
#  ['버스',
#   '사랑',
#   '약혼녀',
#   '이별',
#   '자살',
#   '시도',
#   '레너드',
#   '호아킨',
#   '피닉스',
#   '성격',
#   '산드라',
#   '네사',
#   '이웃',
#   '치명',
#   '미모',
#   '소유자',
#   '미쉘',
#   '기네스',
#   '펠트',
#   '미쉘',
#   '다른',
#   '남자',
#   '사실',
#   '그녀',
#   '레너드',
#   '자신',
#   '주체'],
#  ['범죄',
#   '도시',
#   '서울',
#   '하얼빈',
#   '단숨',
#   '기존',
#   '조직',
#   '장악',
#   '가장',
#   '세력',
#   '식이',
#   '보스',
#   '황사',
#   '조재윤',
#   '위협',
#   '도시',
#   '일대',
#   '최강',
#   '자로',
#   '급부',
#   '신흥',
#   '범죄',
#   '조직',
#   '보스',
#   '장첸',
#   '윤계상',
#   '대한민국',
#   '장첸',
#   '윤계상',
#   '일당',
#   '잡기',
#   '오직',
#   '주먹',
#   '도시',
#   '평화',
#   '유지',
#   '괴물',
#   '형사',
#   '석도',
#   '마동석',
#   '인간미',
#   '리더',
#   '전일',
#   '귀화',
#   '반장',
#   '강력반',
#   '작전',
#   '강력반',
#   '형사',
#   '조폭',
#   '소탕',
#   '작전',
#   '시작'],
#  ['폴로',
#   '니드',
#   '관용',
#   '세기',
#   '프랑스',
#   '매춘굴',
#   '폴로',
#   '니드',
#   '관용',
#   '창녀',
#   '외부',
#   '격리',
#   '탈출',
#   '구원',
#   '희망',
#   '하루하루',
#   '반면',
#   '남성',
#   '실로',
#   '도피',
#   '그로',
#   '다른',
#   '자유',
#   '각자',
#   '해방',
#   '장소',
#   '시대',
#   '변화',
#   '산업화',
#   '시대',
#   '몰락',
#   '현실',
#   '섹스',
#   '세계',
#   '다른',
#   '욕망',
#   '현실',
#   '판타지'],
#  ['스파이더맨',
#   '크로스',
#   '유니버스',
#   '패키지',
#   '자막',
#   '더빙',
#   '부가',
#   '영상',
#   '스파이더맨',
#   '스파이더맨',
#   '여러',
#   '장통',
#   '스파이더맨',
#   '마일',
#   '모랄레스',
#   '다른',
#   '평행',
#   '세계',
#   '스파이더',
#   '우먼',
#   '모든',
#   '차원',
#   '멀티버스',
#   '스파이더맨',
#   '질서',
#   '신념',
#   '상치',
#   '균열',
#   '상상',
#   '이상',
#   '멀티버스',
#   '세계',
#   '린다'],
#  ['아트',
#   '오브',
#   '러브',
#   '커플',
#   '성적',
#   '갈등',
#   '은밀',
#   '자극',
#   '성적',
#   '욕망',
#   '통해',
#   '서로',
#   '정체',
#   '사랑',
#   '내용',
#   '영화'],
#  ['육사오',
#   '당첨',
#   '로또',
#   '말년',
#   '병장',
#   '천우',
#   '심장',
#   '잠시',
#   '순간',
#   '실수',
#   '바람',
#   '타고',
#   '군사분계선',
#   '로또',
#   '멘탈',
#   '기필코',
#   '남쪽',
#   '당첨',
#   '로또',
#   '북한',
#   '병사',
#   '용호',
#   '남조선',
#   '인민',
#   '고혈',
#   '육사오',
#   '종이',
#   '쪼가리',
#   '무려',
#   '당첨',
#   '당첨',
#   '눈앞',
#   '위기',
#   '천우',
#   '종이',
#   '쪼가리',
#   '로또',
#   '당첨',
#   '용호',
#   '여기',
#   '상치',
#   '멤버',
#   '합류',
#   '사수',
#   '결성',
#   '아슬아슬',
#   '협상',
#   '시작'],
#  ['분노',
#   '질주',
#   '라이드',
#   '오어',
#   '디젤',
#   '패밀리',
#   '운명',
#   '단테',
#   '제이슨',
#   '모모',
#   '과거',
#   '그림자',
#   '모든',
#   '파괴',
#   '단테',
#   '산산',
#   '패밀리',
#   '모두',
#   '목숨',
#   '함정',
#   '마지막',
#   '질주',
#   '시작'],
#  ['극장전',
#   '극장',
#   '영화',
#   '이름',
#   '상원',
#   '수능',
#   '시험',
#   '마치',
#   '용돈',
#   '종로',
#   '거리',
#   '안경점',
#   '중학교',
#   '첫사랑',
#   '살의',
#   '우리',
#   '극장',
#   '관객',
#   '이름',
#   '김동수',
#   '오늘',
#   '종로',
#   '극장',
#   '선배',
#   '감독',
#   '영화',
#   '영화',
#   '주인공',
#   '예전',
#   '모습',
#   '극장',
#   '거짓말',
#   '영화',
#   '주인공',
#   '여배우',
#   '이름',
#   '최영',
#   '그녀',
#   '역시',
#   '영화',
#   '인파',
#   '말보로',
#   '담배',
#   '동창회',
#   '부회장',
#   '녀석',
#   '저녁',
#   '선배',
#   '감독',
#   '후원',
#   '모임',
#   '전화',
#   '사실',
#   '선배',
#   '지금',
#   '입원',
#   '중이',
#   '가야',
#   '하나',
#   '하나',
#   '무작정',
#   '종로',
#   '영화',
#   '등장',
#   '사람',
#   '사인',
#   '여배우',
#   '그녀',
#   '역시',
#   '영화',
#   '순례',
#   '중인',
#   '용기',
#   '대해',
#   '오늘',
#   '그녀',
#   '운명'],
#  ['결심',
#   '정상',
#   '추락',
#   '남자',
#   '변사',
#   '사건',
#   '담당',
#   '형사',
#   '박해일',
#   '사망자',
#   '아내',
#   '탕웨이',
#   '마주',
#   '걱정',
#   '마침내',
#   '남편',
#   '죽음',
#   '동요',
#   '보이지',
#   '경찰',
#   '보통',
#   '유가족',
#   '다른',
#   '용의',
#   '선상',
#   '올린다',
#   '사건',
#   '당일',
#   '알리바이',
#   '문과',
#   '잠복',
#   '수사',
#   '통해',
#   '그녀',
#   '관심',
#   '좀처럼',
#   '짐작',
#   '상대',
#   '자신',
#   '의심',
#   '조금',
#   '진심',
#   '용의자',
#   '용의자',
#   '의심',
#   '관심',
#   '동시',
#   '형사',
#   '결심'],
#  ['생활',
#   '발견',
#   '연극',
#   '제법',
#   '배우',
#   '경수',
#   '김상경',
#   '감독',
#   '영화',
#   '출연',
#   '흥행',
#   '시원',
#   '런닝',
#   '개런티',
#   '부득부득',
#   '약속',
#   '차기작',
#   '캐스팅',
#   '선배',
#   '춘천',
#   '경수',
#   '자신',
#   '여자',
#   '명숙',
#   '예지원',
#   '무용가',
#   '그녀',
#   '얼굴',
#   '몸매',
#   '그녀',
#   '갑작스레',
#   '경수',
#   '호감',
#   '표시',
#   '사이',
#   '얼떨결',
#   '진전',
#   '사실',
#   '그녀',
#   '선배',
#   '여인',
#   '춘천',
#   '기억',
#   '주행',
#   '기차',
#   '오른',
#   '경수',
#   '선영',
#   '추상미',
#   '선영',
#   '무작정',
#   '그녀',
#   '태도',
#   '다음',
#   '그녀',
#   '경수',
#   '선영',
#   '선언',
#   '우리',
#   '만난'],
#  ['무덤',
#   '시골',
#   '마을',
#   '미모',
#   '여성',
#   '작가',
#   '제니퍼',
#   '버틀러',
#   '도시',
#   '전원',
#   '분위기',
#   '만끽',
#   '혼자',
#   '산장',
#   '그녀',
#   '존재',
#   '동네',
#   '청년',
#   '보안관',
#   '그녀',
#   '몰래',
#   '그녀',
#   '강간',
#   '폭행',
#   '그녀',
#   '자신',
#   '상처',
#   '가해자',
#   '복수',
#   '시작'],
#  ['블라인드',
#   '보지',
#   '루벤',
#   '후천',
#   '시력',
#   '짐승',
#   '어머니',
#   '사람',
#   '고용',
#   '가지',
#   '낭독',
#   '마리',
#   '만남',
#   '루벤',
#   '제압',
#   '마리',
#   '학대',
#   '얼굴',
#   '온몸',
#   '상처',
#   '다른',
#   '모습',
#   '사람',
#   '시선',
#   '피해',
#   '루벤',
#   '자신',
#   '루벤',
#   '여왕',
#   '마리',
#   '기품',
#   '목소리',
#   '단호',
#   '행동',
#   '관심',
#   '마리',
#   '아주',
#   '모습',
#   '상상',
#   '사랑',
#   '누군가',
#   '사랑',
#   '처음',
#   '마리',
#   '역시',
#   '낯선',
#   '감정',
#   '사랑',
#   '마음',
#   '루벤',
#   '수술',
#   '치료',
#   '마리',
#   '자신',
#   '보고',
#   '모든',
#   '루벤',
#   '마리',
#   '방황'],
#  ['비공식',
#   '작전',
#   '비공식',
#   '하루하루',
#   '지뢰',
#   '중동',
#   '외교관',
#   '민준',
#   '하정우',
#   '수화기',
#   '너머',
#   '개월',
#   '레바논',
#   '실종',
#   '외교관',
#   '암호',
#   '메시지',
#   '미국',
#   '발령',
#   '희망',
#   '포부',
#   '가득',
#   '비공식',
#   '동료',
#   '구출',
#   '임무',
#   '자원',
#   '레바논',
#   '공항',
#   '도착',
#   '직후',
#   '몸값',
#   '공항',
#   '경비',
#   '대의',
#   '총알',
#   '세례',
#   '피해',
#   '한국인',
#   '택시',
#   '기사',
#   '판수',
#   '주지훈',
#   '민준',
#   '갱단',
#   '노리',
#   '지뢰',
#   '상황',
#   '한국인',
#   '판수',
#   '수상',
#   '인간',
#   '동료'],
#  ['레볼루셔',
#   '너리',
#   '로드',
#   '반한',
#   '에이프릴',
#   '케이트',
#   '윈슬렛',
#   '프랭크',
#   '레오나르도',
#   '디카프리오',
#   '결혼',
#   '가정',
#   '뉴욕',
#   '맨하탄',
#   '정도',
#   '교외',
#   '지역',
#   '레볼루셔',
#   '너리',
#   '로드',
#   '가장',
#   '보금자리',
#   '꾸리',
#   '사람',
#   '모두',
#   '안정',
#   '레볼루셔',
#   '너리',
#   '로드',
#   '사랑',
#   '가정',
#   '보이',
#   '반복',
#   '일상',
#   '탈출',
#   '에이프릴',
#   '프랭크',
#   '모든',
#   '파리',
#   '이민',
#   '사람',
#   '회사',
#   '찰나',
#   '프랭크',
#   '승진',
#   '권유',
#   '모든',
#   '파리',
#   '에이프릴',
#   '현실',
#   '안정',
#   '프랭크',
#   '서로',
#   '사랑',
#   '현실',
#   '이상',
#   '사이',
#   '갈등',
#   '사람',
#   '선택'],
#  ['여자',
#   '남자',
#   '미래',
#   '성현아',
#   '김태우',
#   '연인',
#   '문호',
#   '유지태',
#   '후배',
#   '우연',
#   '사건',
#   '마음',
#   '소원',
#   '미국',
#   '유학',
#   '선배',
#   '연인',
#   '짝사랑',
#   '문호',
#   '유학',
#   '계기',
#   '그녀',
#   '연인',
#   '문호',
#   '남녀',
#   '연락',
#   '각자',
#   '만난',
#   '대학',
#   '선후배',
#   '문호',
#   '선배',
#   '유학',
#   '예비',
#   '영화',
#   '감독',
#   '후배',
#   '문호',
#   '부인과',
#   '서울',
#   '유명',
#   '대학',
#   '강사',
#   '남자',
#   '동네',
#   '중국집',
#   '낮술',
#   '무료',
#   '시간',
#   '우리',
#   '지금',
#   '취기',
#   '오른',
#   '사이',
#   '연인',
#   '갑자기',
#   '화제',
#   '각기',
#   '다른',
#   '모습',
#   '추억',
#   '낮술',
#   '남자',
#   '대감',
#   '내심',
#   '불안감',
#   '부천',
#   '돌발행동',
#   '막상',
#   '얼굴',
#   '남자',
#   '욕망',
#   '오직',
#   '단둘',
#   '기회',
#   '호시탐탐',
#   '남자',
#   '행동',
#   '일단',
#   '보기',
#   '남자',
#   '각자',
#   '미래',
#   '만난',
#   '남자',
#   '미래'],
#  ['장화',
#   '고양이',
#   '모험',
#   '패키지',
#   '자막',
#   '더빙',
#   '아홉',
#   '목숨',
#   '하나',
#   '목숨',
#   '장화',
#   '고양이',
#   '마지막',
#   '목숨',
#   '히어로',
#   '대신',
#   '반려',
#   '선택',
#   '마지막',
#   '기회',
#   '바로',
#   '소원',
#   '지도',
#   '목숨',
#   '히어로',
#   '장화',
#   '고양이',
#   '뜻밖',
#   '동료',
#   '앙숙',
#   '파트너',
#   '키티',
#   '친구',
#   '라면',
#   '모든',
#   '강아지',
#   '페로',
#   '소원',
#   '찾기',
#   '다른',
#   '빌런',
#   '새해',
#   '모험',
#   '시작'],
#  ['마스터링',
#   '미래',
#   '배경',
#   '소설',
#   '작가',
#   '차우',
#   '평소',
#   '사랑',
#   '여성',
#   '만남',
#   '지속',
#   '호텔',
#   '묵고',
#   '바이',
#   '과도',
#   '육체',
#   '관계',
#   '바이',
#   '진심',
#   '사랑',
#   '호텔',
#   '사장',
#   '징웬',
#   '도움',
#   '소설',
#   '쓰기',
#   '시작',
#   '차우',
#   '그녀',
#   '사랑',
#   '차우',
#   '사랑',
#   '투영',
#   '소설',
#   '결말',
#   '무엇'],
#  ['파리',
#   '가려진',
#   '도시',
#   '파리',
#   '낭만',
#   '생각',
#   '불현듯',
#   '사랑',
#   '사랑',
#   '에밀리',
#   '사랑',
#   '사랑',
#   '앰버',
#   '위트',
#   '사랑',
#   '카미유',
#   '사랑',
#   '우리',
#   '전부',
#   '생각',
#   '사랑',
#   '도시',
#   '파리'],
#  ['아트',
#   '레이',
#   '데스',
#   '가문',
#   '후계',
#   '티모시',
#   '샬라메',
#   '시공',
#   '초월',
#   '존재',
#   '자전',
#   '우주',
#   '구원',
#   '예지',
#   '자의',
#   '운명',
#   '계시',
#   '매일',
#   '키스',
#   '행성',
#   '여인',
#   '모래언덕',
#   '키스',
#   '방울',
#   '사막',
#   '우주',
#   '가장',
#   '물질',
#   '환각제',
#   '스파이스',
#   '생산',
#   '지로',
#   '차지',
#   '전쟁',
#   '황제',
#   '명령',
#   '아트',
#   '레이',
#   '데스',
#   '가문',
#   '죽음',
#   '키스',
#   '응답',
#   '두려움',
#   '시작'],
#  ['인간중독',
#   '모두',
#   '신임',
#   '승승장구',
#   '중인',
#   '교육',
#   '대장',
#   '김진평',
#   '송승헌',
#   '남편',
#   '장군',
#   '야망',
#   '진평',
#   '아내',
#   '이숙',
#   '조여정',
#   '김진평',
#   '부하',
#   '충성',
#   '맹세',
#   '우진',
#   '온주완',
#   '아내',
#   '종가',
#   '임지연',
#   '이사',
#   '진평',
#   '우진',
#   '아내',
#   '만남',
#   '누구',
#   '비밀',
#   '간직',
#   '여인',
#   '그녀',
#   '진평',
#   '사람',
#   '상류층',
#   '관사',
#   '누구',
#   '치명',
#   '스캔들',
#   '시작',
#   '당신',
#   '수가',
#   '가슴'],
#  ['노바디',
#   '웍스',
#   '음향',
#   '전문가',
#   '피터',
#   '정신과',
#   '의사',
#   '줄리',
#   '아이',
#   '풍족',
#   '단란',
#   '피터',
#   '줄리',
#   '부탁',
#   '아내',
#   '친구',
#   '마틴',
#   '영화',
#   '완성',
#   '돕기',
#   '마틴',
#   '피터',
#   '줄리',
#   '생기',
#   '매력',
#   '마틴',
#   '가족',
#   '모두',
#   '호감',
#   '피터',
#   '작업',
#   '자신감',
#   '열정',
#   '그녀',
#   '육체',
#   '관계',
#   '줄리',
#   '그녀',
#   '성적',
#   '호기심',
#   '환자',
#   '앤디',
#   '노골',
#   '대시',
#   '거부',
#   '가족',
#   '구성원',
#   '모두',
#   '감정',
#   '와중',
#   '피터',
#   '마틴',
#   '자신',
#   '조수',
#   '데이빗',
#   '파티',
#   '모습',
#   '발견',
#   '혼란'],
#  ['바비',
#   '부가',
#   '영상',
#   '제공',
#   '무엇',
#   '바비',
#   '랜드',
#   '바비',
#   '현실',
#   '세계',
#   '이어진',
#   '포털',
#   '균열',
#   '발견',
#   '해결',
#   '여정'],
#  ['바빌론', '위태', '고대', '도시', '바빌론', '비유', '할리우드', '하나', '사람', '쟁취', '매혹'],
#  ['탑건',
#   '매버릭',
#   '최고',
#   '파일럿',
#   '전설',
#   '인물',
#   '매버릭',
#   '크루즈',
#   '자신',
#   '졸업',
#   '훈련',
#   '학교',
#   '교관',
#   '발탁',
#   '명성',
#   '팀원',
#   '매버릭',
#   '지시',
#   '무시',
#   '실전',
#   '방불',
#   '상공',
#   '훈련',
#   '전설',
#   '조종',
#   '실력',
#   '모두',
#   '압도',
#   '매버릭',
#   '지휘',
#   '아래',
#   '팀워크',
#   '팀원',
#   '국경',
#   '임무',
#   '자매',
#   '버릭',
#   '자신',
#   '동료',
#   '마지막',
#   '하늘',
#   '비행'],
#  ['브레이',
#   '로스쿨',
#   '여대생',
#   '장학금',
#   '성격',
#   '그녀',
#   '학교',
#   '가장',
#   '인기',
#   '남학생',
#   '에릭',
#   '시선',
#   '친구',
#   '브룩',
#   '그녀',
#   '공개',
#   '망신',
#   '광경',
#   '다른',
#   '부잣집',
#   '집안',
#   '알렉스',
#   '위로',
#   '브룩',
#   '복수',
#   '하라',
#   '에릭',
#   '유혹',
#   '역시',
#   '처음',
#   '모험',
#   '학교',
#   '장학',
#   '회장',
#   '브룩',
#   '아버지',
#   '장학금',
#   '박탈',
#   '또한',
#   '설상가상',
#   '브룩',
#   '직장',
#   '마저',
#   '절망',
#   '알렉스',
#   '도움',
#   '부쩍',
#   '사이',
#   '성적',
#   '긴장감',
#   '감돈',
#   '브룩',
#   '복수',
#   '방법',
#   '의논',
#   '알렉스',
#   '자신',
#   '새엄마',
#   '알렉스',
#   '자신',
#   '브룩',
#   '보답',
#   '알렉스',
#   '새엄마',
#   '제안',
#   '농담',
#   '다음',
#   '브룩',
#   '시체',
#   '발견',
#   '알렉스',
#   '자신',
#   '약속',
#   '상기',
#   '자신',
#   '알렉스',
#   '이용',
#   '배신',
#   '몸서리'],
#  ['리바운드',
#   '농구',
#   '선수',
#   '출신',
#   '공익',
#   '근무',
#   '요원',
#   '양현',
#   '해체',
#   '위기',
#   '부산',
#   '중앙',
#   '농구부',
#   '신임',
#   '코치',
#   '발탁',
#   '전국',
#   '대회',
#   '경기',
#   '상대',
#   '고교',
#   '농구',
#   '최강',
#   '용산고',
#   '팀워크',
#   '중앙',
#   '몰수',
#   '치욕',
#   '결과',
#   '학교',
#   '농구부',
#   '해체',
#   '논의',
#   '양현',
#   '고교',
#   '시절',
#   '선수',
#   '주목',
#   '천재',
#   '슬럼프',
#   '가드',
#   '기범',
#   '부상',
#   '스몰',
#   '포워드',
#   '규혁',
#   '점프',
#   '축구선수',
#   '출신',
#   '괴력',
#   '센터',
#   '순규',
#   '길거리',
#   '농구',
#   '파워',
#   '포워드',
#   '강호',
#   '농구',
#   '경력',
#   '차지',
#   '만년',
#   '벤치',
#   '식스',
#   '재윤',
#   '농구',
#   '열정',
#   '만렙',
#   '자칭',
#   '마이클',
#   '조던',
#   '진욱',
#   '아무',
#   '주목',
#   '약체',
#   '신임',
#   '코치',
#   '명의',
#   '선수',
#   '전국',
#   '고교',
#   '농구대회',
#   '기적',
#   '모두',
#   '불가능',
#   '우리',
#   '리바운드',
#   '다른',
#   '기회'],
#  ['사랑',
#   '흥정',
#   '거액',
#   '복권',
#   '당첨',
#   '남자',
#   '프랑수아',
#   '베르나르',
#   '캄팡',
#   '모든',
#   '남자',
#   '선망',
#   '여인',
#   '다니엘',
#   '모니카',
#   '벨루치',
#   '유로',
#   '대신',
#   '유로',
#   '복권',
#   '당첨',
#   '제안',
#   '제안',
#   '다니엘',
#   '자신',
#   '해주',
#   '프랑수아',
#   '마음',
#   '사실',
#   '다니엘',
#   '암흑가',
#   '보스',
#   '샤를',
#   '라르',
#   '드빠르디유',
#   '여자',
#   '관계',
#   '샤를',
#   '다니엘',
#   '사이',
#   '프랑수아',
#   '흥정',
#   '시작'],
#  ['밀수',
#   '물속',
#   '한길',
#   '사람',
#   '바닷가',
#   '마을',
#   '화학',
#   '공장',
#   '하루아침',
#   '일자리',
#   '해녀',
#   '살기',
#   '방법',
#   '승부사',
#   '춘자',
#   '김혜수',
#   '바다',
#   '물건',
#   '밀수',
#   '세계',
#   '해녀',
#   '리더',
#   '진숙',
#   '염정아',
#   '제안',
#   '일임',
#   '생계',
#   '감히',
#   '결단',
#   '해녀',
#   '진숙',
#   '전국구',
#   '밀수',
#   '상사',
#   '밀수',
#   '본격',
#   '일확천금',
#   '생일',
#   '기회',
#   '사람',
#   '서로',
#   '밀수',
#   '시작',
#   '물길',
#   '자가',
#   '돈길',
#   '주인'],
#  ['에너미',
#   '안정',
#   '직업',
#   '매력',
#   '여자친구',
#   '일상',
#   '아담',
#   '영화',
#   '자신',
#   '배우',
#   '발견',
#   '호기심',
#   '이후',
#   '각자',
#   '몰래',
#   '염탐',
#   '사람',
#   '서로',
#   '여자',
#   '불안',
#   '혼란'],
#  ['스파이',
#   '전운',
#   '냉전시대',
#   '소련',
#   '군사',
#   '정보',
#   '레크',
#   '대령',
#   '은정',
#   '부의',
#   '피해',
#   '핵전쟁',
#   '위기',
#   '중대',
#   '기밀',
#   '전하',
#   '고자',
#   '협력',
#   '소련',
#   '기밀',
#   '문서',
#   '입수',
#   '영국',
#   '사업가',
#   '그레빌',
#   '스파이',
#   '고용',
#   '잠입',
#   '정체',
#   '런던',
#   '모스크바',
#   '그레빌',
#   '레크',
#   '대령',
#   '은밀',
#   '관계',
#   '계속',
#   '의심',
#   '가장',
#   '사람',
#   '가장',
#   '첩보',
#   '실화',
#   '때론',
#   '사람',
#   '용기',
#   '세상'],
#  ['공동',
#   '경비',
#   '구역',
#   '판문점',
#   '공동',
#   '경비',
#   '구역',
#   '다리',
#   '초소',
#   '북한',
#   '초소',
#   '신하균',
#   '총상',
#   '살해',
#   '사건',
#   '발생',
#   '사건',
#   '이후',
#   '북한',
#   '남한',
#   '기습',
#   '테러',
#   '공격',
#   '남한',
#   '북한',
#   '납치',
#   '각각',
#   '주장',
#   '양국',
#   '남북한',
#   '실무',
#   '협조',
#   '스위스',
#   '스웨덴',
#   '구성',
#   '중립국',
#   '감독',
#   '위원회',
#   '책임',
#   '사관',
#   '기용',
#   '수사',
#   '착수',
#   '극적',
#   '합의',
#   '중립국',
#   '감독',
#   '위원회',
#   '책임',
#   '사관',
#   '쮜리히',
#   '법대',
#   '출신',
#   '한국',
#   '스위스인',
#   '소령',
#   '이영애',
#   '파견',
#   '처음',
#   '한국',
#   '입국',
#   '모두',
#   '피의자',
#   '인도',
#   '거부',
#   '관계',
#   '당국',
#   '협조',
#   '태도',
#   '수사',
#   '초기',
#   '어려움',
#   '사건',
#   '당사자',
#   '남한',
#   '이수혁',
#   '병장',
#   '이병헌',
#   '북한',
#   '경필',
#   '중사',
#   '송강호',
#   '사건',
#   '정황',
#   '서로',
#   '상반',
#   '진술',
#   '반복',
#   '수사',
#   '점차',
#   '미궁',
#   '사건',
#   '최초',
#   '목격자',
#   '남성',
#   '일병',
#   '김태우',
#   '진술',
#   '의혹',
#   '수사',
#   '주변',
#   '인물',
#   '확대',
#   '사건',
#   '은폐',
#   '축소',
#   '남북한',
#   '상부',
#   '조직',
#   '음모',
#   '극도',
#   '혼돈',
#   '상태',
#   '피의자',
#   '중립국',
#   '감독',
#   '위원회',
#   '미온',
#   '태도',
#   '계속',
#   '어려움',
#   '시체',
#   '부검',
#   '증거물',
#   '조사',
#   '공격',
#   '추적',
#   '점차',
#   '진실',
#   '가까이',
#   '접근',
#   '간다',
#   '사건',
#   '전모',
#   '남성',
#   '식이',
#   '돌연',
#   '투신',
#   '자살',
#   '시도',
#   '사건',
#   '계기',
#   '상부',
#   '조직',
#   '아버지',
#   '과거',
#   '국전',
#   '참전',
#   '인민군',
#   '폭로',
#   '중립국',
#   '감독',
#   '위원회',
#   '사주',
#   '수사',
#   '전권',
#   '해임',
#   '통보',
#   '남한',
#   '병사',
#   '이수혁',
#   '병장',
#   '북한',
#   '초소',
#   '최초',
#   '목격자',
#   '남성',
#   '일병',
#   '자살',
#   '시도',
#   '북한',
#   '경필',
#   '중사',
#   '무엇',
#   '숨기',
#   '그녀',
#   '진실',
#   '마지막',
#   '시도',
#   '감행'],
#  ['플래시',
#   '부가',
#   '영상',
#   '제공',
#   '시공간',
#   '붕괴',
#   '세계',
#   '차원',
#   '다른',
#   '히어로',
#   '스피드',
#   '물체',
#   '투과',
#   '전기',
#   '방출',
#   '자체',
#   '회복',
#   '천재',
#   '두뇌',
#   '능력',
#   '자랑',
#   '존재',
#   '제로',
#   '저스티스',
#   '리그',
#   '궂은일',
#   '히어로',
#   '플래시',
#   '자신',
#   '속도',
#   '달리',
#   '시공간',
#   '이동',
#   '능력',
#   '브루스',
#   '웨인',
#   '만류',
#   '무시',
#   '상처',
#   '과거',
#   '시간',
#   '역행',
#   '의도',
#   '장소',
#   '불시',
#   '플래시',
#   '멀티버스',
#   '세상',
#   '다른',
#   '자신',
#   '맞닥뜨리',
#   '메타',
#   '휴먼',
#   '흔적',
#   '모든',
#   '뒤엉킨',
#   '세상',
#   '마주',
#   '플래시',
#   '자신',
#   '모습',
#   '전혀',
#   '나이',
#   '은퇴',
#   '배트맨',
#   '크립톤',
#   '행성',
#   '슈퍼걸',
#   '도움',
#   '외계',
#   '침공',
#   '시간',
#   '차원',
#   '붕괴',
#   '지구'],
#  ['아포칼립토',
#   '거대',
#   '문명',
#   '외세',
#   '정복',
#   '부로',
#   '붕괴',
#   '듀런트',
#   '마야문명',
#   '번창',
#   '시절',
#   '부족',
#   '마을',
#   '전사',
#   '표범',
#   '가족',
#   '나날',
#   '전사',
#   '구성',
#   '침략',
#   '마을',
#   '습격',
#   '부족',
#   '학살',
#   '남녀',
#   '왕국',
#   '발생',
#   '표범',
#   '혼란',
#   '아내',
#   '아들',
#   '우물',
#   '자신',
#   '인질',
#   '죽음',
#   '위기',
#   '상황',
#   '겨우',
#   '탈출',
#   '표범',
#   '우물',
#   '가족',
#   '추적',
#   '계속',
#   '맹수',
#   '습격',
#   '늪지',
#   '생명',
#   '위협',
#   '요소',
#   '무엇',
#   '최강',
#   '전사',
#   '구성',
#   '추격',
#   '생명',
#   '위협',
#   '죽음',
#   '손길',
#   '가운데',
#   '표범',
#   '도리어',
#   '기상',
#   '외한',
#   '공격',
#   '시작'],
#  ['세레나',
#   '열정',
#   '야망',
#   '목재',
#   '사업가',
#   '조지',
#   '팸버튼',
#   '만난',
#   '세레나',
#   '불꽃',
#   '사랑',
#   '결혼',
#   '골인',
#   '결혼',
#   '조지',
#   '사업',
#   '번성',
#   '나날',
#   '조지',
#   '팔로',
#   '부하',
#   '배신',
#   '설상가상',
#   '세레나',
#   '조지',
#   '충격',
#   '과거',
#   '관계',
#   '파국'],
#  ['희망',
#   '남자',
#   '예순',
#   '나이',
#   '정력',
#   '매력',
#   '루돌프',
#   '루돌프',
#   '사위',
#   '레이',
#   '반대',
#   '거짓말',
#   '바로',
#   '생활',
#   '사나이',
#   '가정',
#   '남편',
#   '레이',
#   '거부',
#   '매력',
#   '여인',
#   '샤를로트',
#   '도발',
#   '유혹',
#   '바람',
#   '레이',
#   '재킷',
#   '여자',
#   '속옷',
#   '발견',
#   '아내',
#   '앨리스',
#   '이로',
#   '어진',
#   '부부싸움',
#   '거기',
#   '루돌프',
#   '마르타',
#   '역시',
#   '결혼',
#   '생활',
#   '종지부',
#   '충격',
#   '사건',
#   '한눈',
#   '팔고',
#   '집착',
#   '기혼',
#   '남녀',
#   '막장',
#   '가족',
#   '사랑',
#   '찾기',
#   '시작'],
#  ['무덤',
#   '모델',
#   '케이티',
#   '고액',
#   '프로필',
#   '사진',
#   '촬영',
#   '낙심',
#   '무료',
#   '사진',
#   '촬영',
#   '전단지',
#   '발견',
#   '스튜디오',
#   '촬영',
#   '사진',
#   '작가',
#   '이반',
#   '노출',
#   '요구',
#   '거절',
#   '그녀',
#   '반한',
#   '사진',
#   '작가',
#   '동생',
#   '조지',
#   '원본',
#   '프로필',
#   '사진',
#   '그녀',
#   '그녀',
#   '겁탈',
#   '처리',
#   '이반',
#   '그녀',
#   '상자',
#   '자신',
#   '지하',
#   '창고',
#   '더욱',
#   '폭행',
#   '죽음',
#   '문턱',
#   '가까스로',
#   '목숨',
#   '그녀',
#   '복수',
#   '결심'],
#  ['어른',
#   '세진',
#   '덜컥',
#   '임산부',
#   '어른',
#   '거리',
#   '세진',
#   '가출',
#   '경력',
#   '동갑',
#   '내기',
#   '주영',
#   '처음',
#   '절친',
#   '세진',
#   '주영',
#   '위기',
#   '순간',
#   '파랑',
#   '머리',
#   '재필',
#   '신지',
#   '세진',
#   '유산',
#   '프로젝트',
#   '시작',
#   '우리',
#   '어른',
#   '가장'],
#  ['언니', '동생', '동생', '어디', '동생', '흔적', '그녀', '분노', '폭발', '다오', '여기', '끝장'],
#  ['경주',
#   '구친',
#   '장례식',
#   '참석',
#   '한국',
#   '북경대',
#   '교수',
#   '최현',
#   '박해일',
#   '문득',
#   '춘화',
#   '기억',
#   '경주로',
#   '경주',
#   '찻집',
#   '아리',
#   '여기',
#   '춘화',
#   '베일',
#   '싸인',
#   '미모',
#   '찻집',
#   '주인',
#   '윤희',
#   '신민아',
#   '대뜸',
#   '춘화',
#   '행방',
#   '수상한',
#   '남자',
#   '최현',
#   '변태',
#   '오인',
#   '신경주역',
#   '과거',
#   '애인',
#   '여정',
#   '윤진서',
#   '경주로',
#   '최현',
#   '만남',
#   '누군가',
#   '내내',
#   '여정',
#   '서울',
#   '보문호',
#   '정이',
#   '서울',
#   '생각',
#   '홀로',
#   '보문',
#   '호수',
#   '산책',
#   '최현',
#   '무언가',
#   '찻집',
#   '아리',
#   '솔로',
#   '발걸음',
#   '계모임',
#   '수상한',
#   '첫인상',
#   '달리',
#   '최현',
#   '모습',
#   '호기심',
#   '윤희',
#   '절친',
#   '친구',
#   '신소율',
#   '형사',
#   '영민',
#   '김태훈',
#   '플로리스트',
#   '선생',
#   '류승완',
#   '교수',
#   '백현',
#   '자신',
#   '경주',
#   '계모임',
#   '초대',
#   '고분',
#   '계모임',
#   '술자리',
#   '거리',
#   '최현',
#   '윤희',
#   '윤희',
#   '짝사랑',
#   '영민',
#   '술김',
#   '고분',
#   '위로',
#   '몰래',
#   '경주',
#   '시내',
#   '풍경',
#   '감상',
#   '윤희',
#   '주의',
#   '시간',
#   '윤희',
#   '최현',
#   '윤희',
#   '최현',
#   '자신',
#   '초대',
#   '단둘',
#   '공간',
#   '사람',
#   '사이',
#   '기류',
#   '시작',
#   '가슴',
#   '로맨틱',
#   '시간여행',
#   '시작'],
#  ['공자',
#   '한번',
#   '타겟',
#   '필리핀',
#   '불법',
#   '경기장',
#   '전전',
#   '어머니',
#   '복싱',
#   '선수',
#   '마르코',
#   '어머니',
#   '수술',
#   '마련',
#   '평생',
#   '아버지',
#   '한국',
#   '정체',
#   '불명',
#   '남자',
#   '공자',
#   '추격',
#   '시작',
#   '마르코',
#   '주위',
#   '쑥대밭',
#   '숨통',
#   '공자',
#   '마르코',
#   '추격',
#   '재벌',
#   '이사',
#   '필리핀',
#   '한국',
#   '마르코',
#   '재회',
#   '미스터리',
#   '인물',
#   '윤주',
#   '각기',
#   '다른',
#   '목적',
#   '하나',
#   '타겟',
#   '무엇',
#   '예측',
#   '혼란',
#   '광기',
#   '마르코',
#   '충격',
#   '진실',
#   '마주',
#   '하나',
#   '타겟',
#   '광기',
#   '추격',
#   '시작'],
#  ['늑대',
#   '사냥',
#   '동남아시아',
#   '도피',
#   '인터폴',
#   '배자',
#   '이송',
#   '교도소',
#   '프론티어',
#   '타이탄',
#   '극악',
#   '무도',
#   '베테',
#   '형사',
#   '필리핀',
#   '마닐라',
#   '항구',
#   '모이',
#   '탈출',
#   '종두',
#   '서인국',
#   '한국',
#   '도일',
#   '동윤',
#   '비롯',
#   '각자',
#   '목적',
#   '계심',
#   '탑승',
#   '한국',
#   '태평양',
#   '가운데',
#   '지금',
#   '보지',
#   '극한',
#   '상황',
#   '마주',
#   '태평양',
#   '가운데',
#   '지옥',
#   '누가'],
#  ['명탐정',
#   '코난',
#   '할로윈',
#   '신부',
#   '극악',
#   '무도',
#   '폭파',
#   '플라먀',
#   '함정',
#   '아무로',
#   '토오루',
#   '모든',
#   '베일',
#   '가려진',
#   '플라먀',
#   '단서',
#   '아무로',
#   '토오루',
#   '경찰',
#   '동기',
#   '마지막',
#   '하루',
#   '동시',
#   '결혼식',
#   '신부',
#   '경시청',
#   '사토',
#   '형사',
#   '예감',
#   '도시',
#   '전체',
#   '인질',
#   '삼은',
#   '플라먀',
#   '아무로',
#   '토오루',
#   '명탐정',
#   '코난',
#   '공조',
#   '시작',
#   '카운트다운',
#   '할로윈',
#   '광란'],
#  ['인민',
#   '복무',
#   '모범',
#   '사병',
#   '사단',
#   '사택',
#   '취사',
#   '무광',
#   '목표',
#   '오직',
#   '아내',
#   '아이',
#   '출세',
#   '사단',
#   '출장',
#   '사이',
#   '시작',
#   '아내',
#   '수련',
#   '유혹',
#   '무광',
#   '자신',
#   '목표',
#   '신념',
#   '보고',
#   '금기',
#   '사랑',
#   '사이',
#   '갈등',
#   '보고',
#   '유혹',
#   '스크린'],
#  ['앤트맨',
#   '와스프',
#   '퀀텀',
#   '매니아',
#   '부가',
#   '영상',
#   '터리',
#   '제공',
#   '슈퍼히어로',
#   '파트너',
#   '스캇',
#   '러드',
#   '호프',
#   '다인',
#   '젤린',
#   '릴리',
#   '호프',
#   '부모',
#   '재닛',
#   '다인',
#   '미셸',
#   '행크',
#   '마이클',
#   '더글라스',
#   '스캇',
#   '캐시',
#   '캐서린',
#   '뉴튼',
#   '미지',
#   '양자',
#   '영역',
#   '세계',
#   '앤트맨',
#   '패밀리',
#   '존재',
#   '무한',
#   '우주',
#   '정복자',
#   '누구',
#   '예상',
#   '모든',
#   '한계',
#   '모험',
#   '시작',
#   '마블',
#   '블록버스터',
#   '무한',
#   '우주',
#   '정복자'],
#  ['노인',
#   '나라',
#   '영화',
#   '사막',
#   '가운데',
#   '사냥',
#   '모스',
#   '브롤',
#   '총격',
#   '전이',
#   '출혈',
#   '낭자',
#   '사건',
#   '현장',
#   '발견',
#   '시작',
#   '모스',
#   '모금',
#   '명의',
#   '생존자',
#   '외면',
#   '이백만',
#   '달러',
#   '가방',
#   '발견',
#   '횡재',
#   '달라',
#   '요구',
#   '거절',
#   '내심',
#   '모스',
#   '새벽녘',
#   '현장',
#   '방문',
#   '때마침',
#   '경찰',
#   '신세',
#   '여기',
#   '이백만',
#   '달러',
#   '가방',
#   '살인마',
#   '안톤',
#   '하비에르',
#   '바르뎀',
#   '사진',
#   '보안관',
#   '토미',
#   '존스',
#   '혼돈',
#   '폭력',
#   '결말',
#   '치달',
#   '간다'],
#  ['셰프',
#   '미슐랭',
#   '스타',
#   '명예',
#   '거머',
#   '프랑스',
#   '최고',
#   '셰프',
#   '아담',
#   '존스',
#   '브래들리',
#   '쿠퍼',
#   '모든',
#   '강박',
#   '증세',
#   '성격',
#   '일자리',
#   '슬럼프',
#   '이내',
#   '자신',
#   '모든',
#   '마지막',
#   '미슐랭',
#   '스타',
#   '도전',
#   '결심',
#   '아담',
#   '분야',
#   '최고',
#   '셰프',
#   '불가능',
#   '실행',
#   '런던',
#   '절대',
#   '미각',
#   '소스',
#   '전문가',
#   '스위니',
#   '시에나',
#   '밀러',
#   '상위',
#   '매혹',
#   '셰프',
#   '미쉘',
#   '사이',
#   '테크닉',
#   '자랑',
#   '파티',
#   '맥스',
#   '리카르도',
#   '스카',
#   '포함',
#   '지원',
#   '레스토랑',
#   '토니',
#   '다니엘',
#   '브륄',
#   '모두',
#   '아담',
#   '실력',
#   '제안',
#   '주방',
#   '열기',
#   '압박',
#   '최강',
#   '셰프',
#   '군단',
#   '완벽',
#   '아담',
#   '사이',
#   '경쟁심',
#   '가을',
#   '불보',
#   '키친',
#   '전쟁',
#   '시작'],
#  ['유령',
#   '유령',
#   '고함',
#   '작전',
#   '시작',
#   '일제강점기',
#   '경성',
#   '항일',
#   '조직',
#   '흑색',
#   '스파이',
#   '유령',
#   '비밀리',
#   '활약',
#   '부임',
#   '경호',
#   '대장',
#   '카이토',
#   '흑색',
#   '총독',
#   '암살',
#   '시도',
#   '조선총독부',
#   '내의',
#   '유령',
#   '영문',
#   '유령',
#   '의심',
#   '벼랑',
#   '외딴',
#   '호텔',
#   '용의자',
#   '총독부',
#   '통신',
#   '감독',
#   '암호',
#   '기록',
#   '담당',
#   '차경',
#   '정무총감',
#   '비서',
#   '유리',
#   '암호',
#   '해독',
#   '담당',
#   '천계',
#   '통신',
#   '직원',
#   '백호',
#   '시간',
#   '하루',
#   '기필코',
#   '동지',
#   '총독',
#   '암살',
#   '작전',
#   '성공',
#   '유령',
#   '사이',
#   '의심',
#   '경계',
#   '유령',
#   '작전'],
#  ['티파니',
#   '아침',
#   '소매',
#   '이브닝',
#   '드레스',
#   '얼굴',
#   '안경',
#   '그녀',
#   '티파니',
#   '보석',
#   '활보',
#   '눈빛',
#   '보석',
#   '몸짓',
#   '새벽',
#   '거리',
#   '그녀',
#   '이름',
#   '홀리',
#   '오드리',
#   '헵번',
#   '사실',
#   '그녀',
#   '사스',
#   '농부',
#   '아내',
#   '그녀',
#   '맨하탄',
#   '정착',
#   '작가',
#   '죠지',
#   '페파드',
#   '홀리',
#   '이웃',
#   '아파트',
#   '부자',
#   '여인',
#   '후원',
#   '곤욕',
#   '애인',
#   '노릇',
#   '매력',
#   '홀리',
#   '점차',
#   '호감',
#   '마음',
#   '중년',
#   '남자',
#   '군다',
#   '한밤',
#   '침대',
#   '그녀',
#   '모습',
#   '고양이',
#   '무료함',
#   '이기',
#   '아파트',
#   '비상',
#   '계단',
#   '기타',
#   '모습',
#   '홀리',
#   '더욱',
#   '사랑'],
#  ['다크',
#   '레이스',
#   '라일',
#   '추리',
#   '탐정',
#   '클럽',
#   '클럽',
#   '활동',
#   '라일',
#   '니콜라스',
#   '홀트',
#   '아들',
#   '엄마',
#   '여동생',
#   '살해',
#   '사건',
#   '구심',
#   '생존자',
#   '증인',
#   '막내',
#   '리비',
#   '샤를',
#   '리즈',
#   '테론',
#   '리비',
#   '기억',
#   '엄마',
#   '언니',
#   '살해',
#   '사건',
#   '목격자',
#   '시절',
#   '충격',
#   '리비',
#   '라일',
#   '사람',
#   '사건',
#   '미심',
#   '부분',
#   '그녀',
#   '경제',
#   '어려움',
#   '조건',
#   '기억',
#   '친구',
#   '트레이',
#   '디온드',
#   '클로이',
#   '모레',
#   '마약',
#   '중독',
#   '사탄',
#   '숭배',
#   '마을',
#   '변태',
#   '낙인',
#   '친구',
#   '마약',
#   '공급',
#   '아빠',
#   '러너',
#   '충격',
#   '인생',
#   '최악',
#   '새벽',
#   '마약',
#   '취한',
#   '여자친구',
#   '디온드라',
#   '가족',
#   '모두',
#   '엄마',
#   '언니',
#   '살해',
#   '오빠',
#   '다른',
#   '누군가'],
#  ['헬로',
#   '케이티',
#   '도시',
#   '샌프란시스코',
#   '시작',
#   '케이티',
#   '긍정',
#   '모습',
#   '어려움',
#   '케이티',
#   '그녀',
#   '브루노',
#   '그녀',
#   '시작'],
#  ['리지',
#   '메사추세츠',
#   '대부호',
#   '가의',
#   '상속',
#   '리지',
#   '세비',
#   '호시탐탐',
#   '아버지',
#   '유산',
#   '새엄마',
#   '삼촌',
#   '하녀',
#   '브리',
#   '크리스틴',
#   '스튜어트',
#   '리지',
#   '은밀',
#   '만남',
#   '시작',
#   '당신',
#   '무엇'],
#  ['악인',
#   '연쇄',
#   '살인마',
#   '표적',
#   '조직',
#   '보스',
#   '동수',
#   '범인',
#   '잡기',
#   '혈안',
#   '강력반',
#   '정태석',
#   '타협',
#   '사람',
#   '연쇄',
#   '살인마',
#   '잡기',
#   '표적',
#   '하나',
#   '하나',
#   '먼저'],
#  ['마녀',
#   '자윤',
#   '정체',
#   '불명',
#   '집단',
#   '무차별',
#   '습격',
#   '마녀',
#   '프로젝트',
#   '진행',
#   '아크',
#   '초토화',
#   '홀로',
#   '소녀',
#   '생애',
#   '처음',
#   '세상',
#   '만난',
#   '경희',
#   '도움',
#   '농장',
#   '일상',
#   '간다',
#   '소녀',
#   '망실',
#   '행방',
#   '책임자',
#   '마녀',
#   '프로젝트',
#   '창시자',
#   '총괄',
#   '지령',
#   '제거',
#   '나선',
#   '본사',
#   '요원',
#   '조현',
#   '경희',
#   '농장',
#   '소유권',
#   '조직',
#   '보스',
#   '용두',
#   '상해',
#   '의문',
#   '인방',
#   '각기',
#   '다른',
#   '목적',
#   '세력',
#   '하나',
#   '시작',
#   '소녀',
#   '본성',
#   '모든',
#   '시작',
#   '더욱',
#   '마녀'],
#  ['패션',
#   '오브',
#   '크라이스트',
#   '제자',
#   '유다',
#   '배신',
#   '예수',
#   '제사장',
#   '불신',
#   '가득',
#   '군중',
#   '신성모독',
#   '죄명',
#   '십자가',
#   '선고',
#   '사람',
#   '탄식',
#   '야유',
#   '예수',
#   '골고다',
#   '언덕',
#   '사랑',
#   '인류',
#   '대신',
#   '예수',
#   '그리스도',
#   '마지막'],
#  ['사제',
#   '서울',
#   '뺑소니',
#   '교통사고',
#   '이후',
#   '의문',
#   '증상',
#   '소녀',
#   '소담',
#   '돌출',
#   '행동',
#   '교단',
#   '김신부',
#   '김윤석',
#   '모두',
#   '반대',
#   '의심',
#   '소녀',
#   '자신',
#   '계획',
#   '준비',
#   '모든',
#   '자격',
#   '부합',
#   '명의',
#   '사제',
#   '상황',
#   '모두',
#   '기피',
#   '가운데',
#   '신학생',
#   '부제',
#   '강동원',
#   '선택',
#   '김신부',
#   '동시',
#   '감시',
#   '미션',
#   '마침내',
#   '소녀',
#   '하루',
#   '기회',
#   '김신부',
#   '부제',
#   '모두',
#   '목숨',
#   '수도',
#   '예식',
#   '시작',
#   '절대',
#   '여기'],
#  ['리플리',
#   '피아노',
#   '조율',
#   '호텔',
#   '보이',
#   '볼일',
#   '리플리',
#   '데이몬',
#   '인생',
#   '주인공',
#   '기회',
#   '행운',
#   '뉴욕',
#   '기회',
#   '파티',
#   '석상',
#   '피아니스트',
#   '흉내',
#   '선박',
#   '부호',
#   '그린',
#   '리프',
#   '제임스',
#   '레본',
#   '리플리',
#   '망나니',
#   '아들',
#   '딕키',
#   '쥬드',
#   '이태리',
#   '부탁',
#   '이태리',
#   '리플리',
#   '딕키',
#   '정보',
#   '수집',
#   '딕키',
#   '재즈',
#   '음반',
#   '이태리',
#   '프린스턴',
#   '대학',
#   '동창',
#   '딕키',
#   '서서히',
#   '접근',
#   '딕키',
#   '연인',
#   '기네스',
#   '팰트',
#   '로우',
#   '리플리',
#   '마치',
#   '자신',
#   '상류사회',
#   '일원',
#   '착각',
#   '평생',
#   '재산',
#   '여인',
#   '인생',
#   '자유',
#   '쾌락',
#   '사랑',
#   '수록',
#   '계약',
#   '기간',
#   '만료',
#   '리플리'],
#  ['앤트맨',
#   '와스프',
#   '퀀텀',
#   '매니아',
#   '세트',
#   '슈퍼히어로',
#   '파트너',
#   '스캇',
#   '러드',
#   '호프',
#   '다인',
#   '젤린',
#   '릴리',
#   '호프',
#   '부모',
#   '재닛',
#   '다인',
#   '미셸',
#   '행크',
#   '마이클',
#   '더글라스',
#   '스캇',
#   '캐시',
#   '캐서린',
#   '뉴튼',
#   '미지',
#   '양자',
#   '영역',
#   '세계',
#   '앤트맨',
#   '패밀리',
#   '존재',
#   '무한',
#   '우주',
#   '정복자',
#   '누구',
#   '예상',
#   '모든',
#   '한계',
#   '모험',
#   '시작',
#   '마블',
#   '블록버스터',
#   '무한',
#   '우주',
#   '정복자'],
#  ['콘크리트',
#   '유토피아',
#   '아파트',
#   '주민',
#   '세상',
#   '대지진',
#   '하루아침',
#   '폐허',
#   '서울',
#   '모든',
#   '오직',
#   '황궁',
#   '아파트',
#   '그대',
#   '소문',
#   '외부',
#   '생존자',
#   '황궁',
#   '아파트',
#   '위협',
#   '시작',
#   '주민',
#   '생존',
#   '하나',
#   '주민',
#   '대표',
#   '중심',
#   '외부',
#   '출입',
#   '아파트',
#   '주민',
#   '규칙',
#   '덕분',
#   '지옥',
#   '바깥',
#   '세상',
#   '달리',
#   '주민',
#   '유토피아',
#   '황궁',
#   '아파트',
#   '생존',
#   '위기',
#   '사이',
#   '상치',
#   '갈등',
#   '시작',
#   '생존',
#   '규칙'],
#  ['새벽',
#   '저주',
#   '전자제품',
#   '판매원',
#   '하루하루',
#   '인생',
#   '살이',
#   '얼마',
#   '남지',
#   '살의',
#   '청년',
#   '추억',
#   '레코드',
#   '수집',
#   '자신',
#   '직업',
#   '목표',
#   '일상',
#   '기쁨',
#   '매력',
#   '지적',
#   '동갑',
#   '내기',
#   '여자',
#   '친구',
#   '리즈',
#   '엄마',
#   '여자친구',
#   '리즈',
#   '실연',
#   '상심',
#   '마음',
#   '다음',
#   '아침',
#   '영국',
#   '정체',
#   '불명',
#   '바이러스',
#   '하루',
#   '아침',
#   '악몽',
#   '세상',
#   '세상',
#   '온통',
#   '사람',
#   '시체',
#   '좀비',
#   '거리',
#   '배회',
#   '심지어',
#   '뒤뜰',
#   '침입',
#   '상황',
#   '좀비',
#   '맞닥뜨리',
#   '좀비',
#   '백수',
#   '죽마고우',
#   '애드',
#   '도움',
#   '사랑',
#   '엄마',
#   '바바라',
#   '여자친구',
#   '리즈',
#   '좀비',
#   '로부터',
#   '분투',
#   '영웅',
#   '청년',
#   '무기',
#   '에드',
#   '좀비'],
#  ['가족',
#   '서울',
#   '장사',
#   '가족',
#   '산장',
#   '운영',
#   '막내딸',
#   '미나',
#   '고호경',
#   '위시',
#   '아버지',
#   '박인환',
#   '어머니',
#   '나문희',
#   '최민식',
#   '오빠',
#   '송강호',
#   '언니',
#   '이윤성',
#   '여섯',
#   '식구',
#   '연지',
#   '주가',
#   '손님',
#   '오지',
#   '가족',
#   '신경',
#   '극도',
#   '미나',
#   '소리',
#   '산장',
#   '주변',
#   '만난',
#   '괴노파',
#   '가족',
#   '아무',
#   '그녀',
#   '관심',
#   '산장',
#   '손님',
#   '가족',
#   '나머지',
#   '해프닝',
#   '친절',
#   '공세',
#   '다음',
#   '손님',
#   '시체',
#   '발견',
#   '경악',
#   '가족',
#   '장사',
#   '지장',
#   '몰래',
#   '시체',
#   '암매장',
#   '투숙',
#   '죽음',
#   '이후',
#   '얼마',
#   '공교',
#   '산장',
#   '투숙',
#   '남녀',
#   '자살',
#   '가족',
#   '극도',
#   '신경',
#   '상태',
#   '시체',
#   '매장',
#   '장소',
#   '음독',
#   '남자',
#   '가족',
#   '매장',
#   '광경',
#   '가족',
#   '남자',
#   '산장',
#   '바로',
#   '등산로',
#   '공사',
#   '예정',
#   '일찍',
#   '시작',
#   '시체',
#   '암매장',
#   '불안',
#   '초조',
#   '가족',
#   '필사',
#   '작업',
#   '저지',
#   '이즈음',
#   '산장',
#   '가족',
#   '소개',
#   '동네',
#   '이장',
#   '김재건',
#   '해결사',
#   '이기영',
#   '고용',
#   '친아버지',
#   '이복',
#   '여동생',
#   '지수원',
#   '해치',
#   '재산',
#   '차지',
#   '음모',
#   '사람',
#   '산장',
#   '가족',
#   '연속',
#   '마치',
#   '게임',
#   '퍼즐',
#   '때로는',
#   '때로는',
#   '가족',
#   '지난',
#   '며칠',
#   '일상',
#   '마침내',
#   '종말'],
#  ['키스',
#   '오브',
#   '뱀파이어',
#   '뱀파이어',
#   '듀나',
#   '인간',
#   '남자',
#   '사랑',
#   '뱀파이어',
#   '치명',
#   '매력',
#   '듀나',
#   '동생',
#   '미미',
#   '등장',
#   '일상',
#   '사랑',
#   '뱀파이어',
#   '듀나',
#   '본능',
#   '뱀파이어',
#   '미미',
#   '그녀',
#   '진짜',
#   '사랑',
#   '시작'],
#  ['아담',
#   '패밀리',
#   '아담',
#   '일가',
#   '가장',
#   '고메스',
#   '라울',
#   '줄리아',
#   '부인',
#   '시아',
#   '젤리',
#   '휴스턴',
#   '웬즈데이',
#   '크리스티나',
#   '리치',
#   '아들',
#   '퍽슬리',
#   '지미',
#   '워크맨',
#   '아담',
#   '일가',
#   '고메스',
#   '페스',
#   '크리스토퍼',
#   '이드',
#   '행방불명',
#   '사실',
#   '페스',
#   '집의',
#   '재산',
#   '여인',
#   '아비게일',
#   '엘리자베스',
#   '윌슨',
#   '아들',
#   '페스',
#   '변장',
#   '고메즈',
#   '페스',
#   '행동',
#   '보고',
#   '의심',
#   '시작',
#   '여러가지',
#   '시험',
#   '과정',
#   '아이',
#   '페스',
#   '정이',
#   '고메즈',
#   '페스',
#   '아비게일',
#   '모자',
#   '음모',
#   '진행',
#   '고메즈',
#   '일가',
#   '음모',
#   '아담',
#   '일가',
#   '어머니',
#   '독재',
#   '염증',
#   '페스',
#   '폭풍',
#   '악인',
#   '자신',
#   '기억',
#   '사실',
#   '진짜',
#   '페스',
#   '가족',
#   '모이',
#   '산다'],
#  ['매일',
#   '아침',
#   '과거',
#   '기억',
#   '남편',
#   '크리스틴',
#   '매일',
#   '아내',
#   '그녀',
#   '누구',
#   '인지',
#   '크리스틴',
#   '상태',
#   '아침',
#   '통화',
#   '기억',
#   '려고',
#   '박사',
#   '무언가',
#   '상치',
#   '기운',
#   '그녀',
#   '박사',
#   '상담',
#   '통해',
#   '자신',
#   '사고',
#   '관련',
#   '충격',
#   '사실',
#   '매일',
#   '아침',
#   '기억',
#   '누구',
#   '상황',
#   '그녀',
#   '자신',
#   '기억'],
#  ['헨리',
#   '제프리',
#   '러쉬',
#   '결혼식',
#   '참석',
#   '고향',
#   '크리스천',
#   '슈나이더',
#   '어머니',
#   '올리버',
#   '레슬리',
#   '아내',
#   '샬롯',
#   '미란다',
#   '오토',
#   '헤드',
#   '결혼',
#   '생활',
#   '어가',
#   '올리버',
#   '사랑',
#   '사람',
#   '상처',
#   '악몽',
#   '자신',
#   '발견',
#   '크리스천',
#   '여기',
#   '결혼식',
#   '분위기',
#   '도취',
#   '어머니',
#   '모두',
#   '과거',
#   '로만',
#   '남아',
#   '어머니',
#   '죽음',
#   '관련',
#   '충격',
#   '진실',
#   '크리스천',
#   '분노'],
#  ['용서',
#   '그녀',
#   '아가씨',
#   '장래성',
#   '그녀',
#   '어머니',
#   '악명',
#   '기질',
#   '도둑',
#   '살인자',
#   '윌리엄',
#   '결혼',
#   '심장',
#   '발작',
#   '그녀',
#   '어머니',
#   '상상',
#   '달리',
#   '죽지',
#   '천연두',
#   '마감',
#   '그때',
#   '와이오밍주',
#   '위스키',
#   '윌리엄',
#   '클린트',
#   '이스트',
#   '우드',
#   '은퇴',
#   '무법자',
#   '열차',
#   '은행',
#   '남녀',
#   '노소',
#   '불문',
#   '살인자',
#   '악명',
#   '과거',
#   '캔사스',
#   '구석',
#   '아들',
#   '돼지',
#   '인생',
#   '아내',
#   '돼지',
#   '전염병',
#   '생활고',
#   '카우보이',
#   '창녀',
#   '얼굴',
#   '사건',
#   '보안관',
#   '리틀',
#   '대거',
#   '화가',
#   '창녀',
#   '악당',
#   '현상금',
#   '스코필드',
#   '울벳',
#   '노리',
#   '업자',
#   '로서',
#   '옛날',
#   '흑인',
#   '총잡이',
#   '레드',
#   '로건',
#   '모건',
#   '프리',
#   '데리',
#   '간다',
#   '로건',
#   '역시',
#   '무법자',
#   '생활',
#   '청산',
#   '부탁',
#   '사람',
#   '위스키',
#   '열차',
#   '총잡이',
#   '잉글리쉬',
#   '리차드',
#   '해리스',
#   '마을',
#   '보안관',
#   '폭행',
#   '당한',
#   '작가',
#   '보상',
#   '소울',
#   '루비',
#   '소설',
#   '소재',
#   '마을',
#   '이후',
#   '사건',
#   '직접',
#   '목격',
#   '지난',
#   '안소니',
#   '페더스',
#   '부인',
#   '몹시',
#   '여행',
#   '그녀',
#   '마지막',
#   '장소',
#   '호즈먼',
#   '카운티',
#   '방문',
#   '윌리엄',
#   '자식',
#   '샌프란시스코',
#   '곡물',
#   '산업',
#   '소문',
#   '페더스',
#   '부인',
#   '자신',
#   '하나',
#   '악명',
#   '기질',
#   '도둑',
#   '살인자',
#   '결혼',
#   '설명'],
#  ['이벤트',
#   '서기',
#   '광속',
#   '속도',
#   '우주',
#   '여행',
#   '탐사선',
#   '이벤트',
#   '호가',
#   '실종',
#   '의문',
#   '이벤트',
#   '즌호',
#   '생존',
#   '신호',
#   '확인',
#   '우주',
#   '우주선',
#   '여러가지',
#   '의문',
#   '생존자',
#   '확인',
#   '구조선',
#   '루이스',
#   '클락',
#   '파견',
#   '밀러',
#   '로렌스',
#   '피쉬',
#   '리더',
#   '구조대',
#   '이벤트',
#   '즌호',
#   '직접',
#   '제작',
#   '윌리엄',
#   '박사',
#   '포함',
#   '밀러',
#   '선장',
#   '비롯',
#   '루이스',
#   '클락',
#   '호의',
#   '대원',
#   '목적지',
#   '해왕성',
#   '궤도',
#   '이벤트',
#   '즌를',
#   '발견',
#   '생명',
#   '흔적',
#   '우주선',
#   '수색',
#   '작업',
#   '벌이',
#   '이벤트',
#   '즌호',
#   '대원',
#   '모두',
#   '상태',
#   '수색',
#   '작업',
#   '투입',
#   '대원',
#   '모두',
#   '환영',
#   '하나',
#   '목숨',
#   '발생',
#   '밀러',
#   '선장',
#   '나머지',
#   '대원',
#   '이벤트',
#   '호가',
#   '가설',
#   '우주선',
#   '리베',
#   '라데',
#   '투테메',
#   '라틴어',
#   '메시지',
#   '구해',
#   '달라',
#   '내용',
#   '사실',
#   '지옥',
#   '당신',
#   '구하라',
#   '것임',
#   '밀러',
#   '선장',
#   '박사',
#   '대원',
#   '철수',
#   '명령',
#   '사실',
#   '이벤트',
#   '즌호',
#   '차원',
#   '차원',
#   '사이',
#   '구멍',
#   '블랙홀',
#   '중력',
#   '동기',
#   '순간',
#   '공간',
#   '이동',
#   '우주선',
#   '루이스',
#   '클락',
#   '대원',
#   '모든',
#   '차원',
#   '우주',
#   '작용',
#   '때문',
#   '자신',
#   '이벤트',
#   '집착',
#   '박사',
#   '중력',
#   '동기',
#   '통해',
#   '차원',
#   '반대편',
#   '우주',
#   '무엇',
#   '매료',
#   '루이스',
#   '클락',
#   '대원',
#   '환영',
#   '악령',
#   '우주선',
#   '악마',
#   '화신',
#   '차원',
#   '통과',
#   '박사',
#   '목숨',
#   '사투'],
#  ['카레',
#   '니나',
#   '왕정',
#   '러시아',
#   '귀부인',
#   '청년',
#   '장교',
#   '비극',
#   '사랑',
#   '톨스토이',
#   '비극',
#   '명작',
#   '이전',
#   '차례',
#   '영화',
#   '작품',
#   '작품',
#   '버나드',
#   '감독',
#   '연출',
#   '프랑스',
#   '배우',
#   '마르',
#   '영국',
#   '배우',
#   '공연',
#   '이전',
#   '작품',
#   '러시아',
#   '여배우',
#   '로크리',
#   '처음',
#   '기록',
#   '프랑스',
#   '잔느',
#   '베가',
#   '미국',
#   '바라가',
#   '처음',
#   '이외',
#   '이탈리아',
#   '헝가리',
#   '독일',
#   '영화',
#   '그레타',
#   '보가',
#   '출연',
#   '사의',
#   '무성영화',
#   '러브',
#   '모두',
#   '명의',
#   '까레리나',
#   '탄생',
#   '그레타',
#   '클레',
#   '런스',
#   '브라운',
#   '감독',
#   '흑백영화',
#   '까레리',
#   '출연',
#   '영국',
#   '비비안',
#   '리가',
#   '출연',
#   '줄리',
#   '비비',
#   '흑백영화',
#   '까레리',
#   '감독',
#   '그레타',
#   '영화',
#   '의상',
#   '세트',
#   '카메라',
#   '흑백',
#   '영화로',
#   '기록',
#   '줄리',
#   '모레',
#   '아르헨티나',
#   '티아',
#   '일로',
#   '소련',
#   '비운',
#   '주인공',
#   '연보',
#   '왕정',
#   '러시아',
#   '대지주',
#   '레닌',
#   '제임스',
#   '폭스',
#   '정숙',
#   '아내',
#   '로서',
#   '테스',
#   '호화',
#   '저택',
#   '안정',
#   '생활',
#   '하나',
#   '생활',
#   '관료',
#   '보수',
#   '남편',
#   '염증',
#   '현실',
#   '그녀',
#   '오빠',
#   '스티',
#   '대니',
#   '휴스턴',
#   '잠시',
#   '테스',
#   '모스크바',
#   '도착',
#   '운명',
#   '사랑',
#   '기차역',
#   '오빠',
#   '친구',
#   '브론',
#   '스키',
#   '만난',
#   '귀족',
#   '생활',
#   '관습',
#   '규율',
#   '드녀',
#   '사랑',
#   '도전',
#   '장교',
#   '브론스키',
#   '왕녀',
#   '키티',
#   '미라',
#   '쉬너',
#   '사랑',
#   '모스크바',
#   '기차',
#   '어머니',
#   '마중',
#   '브론스키',
#   '친구',
#   '동생',
#   '보고',
#   '결혼',
#   '아들',
#   '브론스키',
#   '키티',
#   '사랑',
#   '거부',
#   '끝내',
#   '테스',
#   '브론스키',
#   '공세',
#   '마음',
#   '불륜',
#   '관계',
#   '연애',
#   '사건',
#   '마을',
#   '사실',
#   '남편',
#   '레닌',
#   '이혼',
#   '요구',
#   '그녀',
#   '아들',
#   '심지어',
#   '사교계',
#   '그녀',
#   '즈음',
#   '브론스키',
#   '아이',
#   '임신',
#   '상태',
#   '겨울',
#   '유산',
#   '브론스키',
#   '레닌',
#   '도움',
#   '요청',
#   '레닌',
#   '브론스키',
#   '데리',
#   '이탈리아',
#   '여름',
#   '레닌',
#   '정식',
#   '이혼',
#   '요구',
#   '브론스키',
#   '테스',
#   '이탈리아',
#   '정식',
#   '부부',
#   '사람',
#   '시선',
#   '레닌',
#   '이혼',
#   '아들',
#   '브론스키',
#   '먼저',
#   '시골',
#   '가라',
#   '하자',
#   '아편',
#   '취해',
#   '자살'],
#  ['오늘',
#   '세계',
#   '사랑',
#   '해도',
#   '카미',
#   '토루',
#   '대해',
#   '자고',
#   '전날',
#   '기억',
#   '선행',
#   '기억상실증',
#   '소녀',
#   '마오리',
#   '내일',
#   '마오리',
#   '누구',
#   '기억',
#   '무색',
#   '무취',
#   '소년',
#   '토루',
#   '매일',
#   '사랑',
#   '세계',
#   '불구',
#   '서로',
#   '고백',
#   '반복',
#   '소년',
#   '소녀',
#   '가장',
#   '청춘'],
#  ['스파이더맨',
#   '유니버스',
#   '마일',
#   '모랄레스',
#   '방사',
#   '거미',
#   '스파이더맨',
#   '능력',
#   '가지',
#   '혼란',
#   '마일',
#   '악당',
#   '피터',
#   '파커',
#   '피터',
#   '파커',
#   '마일',
#   '자신',
#   '능력',
#   '가지',
#   '직감',
#   '여러',
#   '평행',
#   '세계',
#   '존재',
#   '마일',
#   '피터',
#   '파커',
#   '이후',
#   '스파이더',
#   '우먼',
#   '스파이더',
#   '스파이더맨',
#   '아르',
#   '스파이',
#   '더햄',
#   '평행',
#   '세계',
#   '공존',
#   '모든',
#   '스파이더맨',
#   '하나',
#   '유니버스',
#   '결성',
#   '스파이더맨',
#   '세계',
#   '스파이더맨',
#   '시대',
#   '린다'],
#  ['나이트',
#   '롤러',
#   '루이스',
#   '제이크',
#   '질렌할',
#   '목격',
#   '교통사고',
#   '현장',
#   '특종',
#   '사건',
#   '현장',
#   '카메라',
#   '매체',
#   '고가',
#   '일명',
#   '나이트',
#   '롤러',
#   '경찰',
#   '도착',
#   '현장',
#   '스케치',
#   '전화',
#   '통해',
#   '가격',
#   '흥정',
#   '냄새',
#   '루이스',
#   '즉시',
#   '캠코더',
#   '경찰',
#   '무전기',
#   '구입',
#   '사건',
#   '현장',
#   '유혈',
#   '난무',
#   '사고',
#   '현장',
#   '촬영',
#   '거래',
#   '루이스',
#   '감각',
#   '지역',
#   '채널',
#   '보도국',
#   '니나',
#   '루소',
#   '적극',
#   '지지',
#   '매번',
#   '더욱',
#   '자극',
#   '충격',
#   '뉴스',
#   '니나',
#   '이상',
#   '충족',
#   '루이스',
#   '최상',
#   '시청률',
#   '승승장구',
#   '자신',
#   '촬영',
#   '도취',
#   '루이스',
#   '특종',
#   '사건',
#   '조작',
#   '특종',
#   '추적',
#   '스릴러'],
#  ['가장',
#   '은퇴',
#   '광고',
#   '에이전시',
#   '보스',
#   '셜리',
#   '맥클레인',
#   '자신',
#   '사망기사',
#   '미리',
#   '컨펌',
#   '사망기사',
#   '기자',
#   '아만다',
#   '프리드',
#   '고용',
#   '엇의',
#   '성격',
#   '주변',
#   '사람',
#   '모두',
#   '저주',
#   '좌절',
#   '엇은',
#   '뜻밖',
#   '제안',
#   '사망기사',
#   '반드시',
#   '고인',
#   '동료',
#   '칭찬',
#   '가족',
#   '사랑',
#   '누군가',
#   '영향',
#   '자신',
#   '와일드',
#   '카드',
#   '가지',
#   '요소',
#   '게다가',
#   '티격',
#   '사이',
#   '말썽',
#   '문제',
#   '소녀',
#   '브렌',
#   '가세',
#   '엇의',
#   '인생',
#   '시작',
#   '마녀',
#   '마지막',
#   '최고',
#   '파트너'],
#  ['오브',
#   '이집트',
#   '인간',
#   '공존',
#   '시절',
#   '번영',
#   '이집트',
#   '제국',
#   '태양',
#   '호루스',
#   '어둠',
#   '세트',
#   '왕위',
#   '강탈',
#   '모든',
#   '도둑',
#   '아내',
#   '호루스',
#   '세트',
#   '지옥',
#   '천국',
#   '세계',
#   '여정',
#   '신들',
#   '관문',
#   '지나',
#   '마침내',
#   '최종',
#   '대결'],
#  ['쁘띠',
#   '마망',
#   '외할머니',
#   '유품',
#   '정리',
#   '엄마',
#   '마리옹',
#   '시골',
#   '넬리',
#   '어린시절',
#   '엄마',
#   '추억',
#   '넬리',
#   '엄마',
#   '이름',
#   '동갑',
#   '내기',
#   '마리옹',
#   '단숨',
#   '서로',
#   '넬리',
#   '마리옹',
#   '넬리',
#   '우연',
#   '만남',
#   '비밀',
#   '비밀',
#   '비밀',
#   '면서',
#   '비밀'],
#  ['포터',
#   '마법사',
#   '포터',
#   '다니엘',
#   '래드클리프',
#   '위압',
#   '버논',
#   '숙부',
#   '챠드',
#   '그리피스',
#   '이모',
#   '페투니',
#   '피오',
#   '욕심',
#   '버릇',
#   '사촌',
#   '더즐리',
#   '갖은',
#   '구박',
#   '계단',
#   '벽장',
#   '생활',
#   '이모',
#   '식구',
#   '역시',
#   '동거',
#   '마찬가지',
#   '이모',
#   '페투니아',
#   '언니',
#   '부부',
#   '기억',
#   '갑지',
#   '존재',
#   '생일',
#   '며칠',
#   '한번',
#   '생일',
#   '파티',
#   '제대로',
#   '생일',
#   '선물',
#   '로서',
#   '기대',
#   '생일',
#   '며칠',
#   '초록색',
#   '잉크',
#   '편지',
#   '배달',
#   '편지',
#   '내용',
#   '생일',
#   '맞이',
#   '전설',
#   '호그와트',
#   '마법',
#   '학교',
#   '입학',
#   '초대장',
#   '생일',
#   '축하',
#   '거인',
#   '해그리드',
#   '정체',
#   '그것',
#   '바로',
#   '능력',
#   '마법사',
#   '해그리드',
#   '지시',
#   '자신',
#   '구박',
#   '이모',
#   '주저',
#   '호그와트',
#   '택한다',
#   '런던',
#   '킹스크로스',
#   '비밀',
#   '호그와트',
#   '특급',
#   '열차',
#   '열차',
#   '호그와트',
#   '마법',
#   '학교',
#   '입학생',
#   '헤르미온느',
#   '레인저',
#   '엠마',
#   '왓슨',
#   '위즐리',
#   '루퍼트',
#   '그린',
#   '친구',
#   '호그와트',
#   '입학',
#   '모험',
#   '세계',
#   '경험',
#   '갖가지',
#   '마법',
#   '또한',
#   '빗자루',
#   '타고',
#   '공중',
#   '경기',
#   '스릴',
#   '만점',
#   '퀴디치',
#   '게임',
#   '스타',
#   '탄생',
#   '머리',
#   '유니콘',
#   '켄타우루스',
#   '히포그리프',
#   '독수리',
#   '머리',
#   '날개',
#   '괴물',
#   '동물',
#   '모험',
#   '호그와트',
#   '지하실',
#   '마법사',
#   '비밀리',
#   '보관',
#   '부모님',
#   '볼드모트',
#   '사실',
#   '볼드모트',
#   '바로',
#   '이마',
#   '번개',
#   '모양',
#   '흉터',
#   '장본인',
#   '볼드모트',
#   '로부터',
#   '마법',
#   '호그와트',
#   '마법',
#   '학교',
#   '필사',
#   '노력'],
#  ['시절인연',
#   '애인',
#   '아이',
#   '임신',
#   '시애틀',
#   '그녀',
#   '쟈쟈',
#   '막무가내',
#   '여자',
#   '보이',
#   '사실',
#   '그녀',
#   '국가',
#   '로부터',
#   '출산',
#   '허가',
#   '아이',
#   '홀로',
#   '시애틀',
#   '방문',
#   '운전기사',
#   '프랭크',
#   '도움',
#   '산후조리원',
#   '애인',
#   '연락',
#   '오지',
#   '낯선',
#   '빈털터리',
#   '쟈쟈',
#   '시작',
#   '그녀',
#   '애인',
#   '계속',
#   '소식',
#   '쟈쟈',
#   '불안',
#   '시간',
#   '문득',
#   '자신',
#   '운전기사',
#   '프랭크',
#   '로부터',
#   '위로',
#   '아이',
#   '위기',
#   '쟈쟈',
#   '사랑',
#   '상처',
#   '프랭크',
#   '사람',
#   '로맨스',
#   '시애틀'],
#  ['모스트',
#   '원티드',
#   '독일',
#   '최고',
#   '스파이',
#   '지금',
#   '정보',
#   '소속',
#   '비밀',
#   '조직',
#   '수장',
#   '군터',
#   '바흐',
#   '필립',
#   '세이모어',
#   '호프만',
#   '정보원',
#   '미끼',
#   '목표',
#   '제거',
#   '재능',
#   '먹잇감',
#   '이사',
#   '인터폴',
#   '지명',
#   '수배',
#   '이사',
#   '아버지',
#   '유산',
#   '찾기',
#   '함부르크',
#   '밀항',
#   '무슬림',
#   '청년',
#   '본능',
#   '이사',
#   '시작',
#   '군터',
#   '이사',
#   '인권',
#   '변호사',
#   '애너벨',
#   '리히터',
#   '레이첼',
#   '맥아',
#   '덤스',
#   '유산',
#   '관리',
#   '은행',
#   '토마스',
#   '브루',
#   '윌렘',
#   '데포',
#   '존재',
#   '사람',
#   '자신',
#   '정보원',
#   '섭외',
#   '이사',
#   '이용',
#   '테러리스트',
#   '자금',
#   '로서',
#   '각국',
#   '정보',
#   '부의',
#   '용의',
#   '선상',
#   '오른',
#   '닥터',
#   '압둘라',
#   '체포',
#   '은밀',
#   '작전',
#   '설계'],
#  ['블랙',
#   '팬서',
#   '와칸',
#   '포에버',
#   '세트',
#   '국왕',
#   '블랙',
#   '팬서',
#   '티찰라',
#   '죽음',
#   '이후',
#   '강대국',
#   '위협',
#   '와칸',
#   '라몬',
#   '슈리',
#   '나키',
#   '코예',
#   '바쿠',
#   '각자',
#   '명감',
#   '와칸',
#   '싸움',
#   '간다',
#   '비브라늄',
#   '패권',
#   '미스터리',
#   '음모',
#   '해저',
#   '모습',
#   '최강',
#   '전사',
#   '와칸',
#   '무차별',
#   '공격',
#   '시작'],
#  ['어디',
#   '버나뎃',
#   '최연',
#   '맥아더',
#   '수상한',
#   '천재',
#   '건축가',
#   '현재',
#   '사회',
#   '제로',
#   '문제',
#   '이웃',
#   '버나뎃',
#   '워커홀릭',
#   '남편',
#   '엘진',
#   '사사건건',
#   '간섭',
#   '동네',
#   '주름',
#   '옆집',
#   '이웃',
#   '오드리',
#   '일거수일투족',
#   '감시',
#   '남편',
#   '비서',
#   '수린',
#   '버나뎃',
#   '소망',
#   '주변',
#   '매일',
#   '소란',
#   '그녀',
#   '폭발',
#   '온라인',
#   '비서',
#   '줄라',
#   '친구',
#   '소원',
#   '가족',
#   '여행',
#   '준비',
#   '버나뎃',
#   '자신',
#   '국제',
#   '범죄',
#   '사실',
#   '조사',
#   '시작',
#   '흔적'],
#  ['글래디에이터',
#   '정기',
#   '로마제국',
#   '영토',
#   '아프리카',
#   '사막',
#   '잉글랜드',
#   '북쪽',
#   '당시',
#   '세계',
#   '인구',
#   '로마',
#   '황제',
#   '지배',
#   '서기',
#   '마르',
#   '커스',
#   '아우렐리우스',
#   '황제',
#   '게르마니아',
#   '정벌',
#   '거의',
#   '마무리',
#   '무렵',
#   '마지막',
#   '하나',
#   '적의',
#   '요새',
#   '함락',
#   '로마',
#   '제국',
#   '평화',
#   '시대',
#   '막바지',
#   '서기',
#   '로마',
#   '두운',
#   '삼림',
#   '명의',
#   '부대',
#   '마치',
#   '폭풍전야',
#   '장군',
#   '신호',
#   '함성',
#   '소리',
#   '하늘',
#   '화살',
#   '점토',
#   '항아리',
#   '난무',
#   '땅위',
#   '병사',
#   '피로',
#   '철인',
#   '황제',
#   '마르쿠스',
#   '아우렐리우스',
#   '리차드',
#   '해리스',
#   '아들',
#   '장군',
#   '막시무스',
#   '러셀',
#   '크로우',
#   '다뉴브',
#   '강가',
#   '전투',
#   '대승',
#   '황제',
#   '마르쿠스',
#   '아우렐리우스',
#   '막시무스',
#   '총애',
#   '아들',
#   '왕위',
#   '넘겨주기',
#   '황제',
#   '아들',
#   '코모',
#   '질투',
#   '분노',
#   '황제',
#   '살해',
#   '왕좌',
#   '코모',
#   '막시무스',
#   '가족',
#   '명령',
#   '가족',
#   '모두',
#   '혼자',
#   '겨우',
#   '막시무스',
#   '노예',
#   '전락',
#   '투기',
#   '검투사',
#   '매일',
#   '훈련',
#   '즉위',
#   '황제',
#   '코모',
#   '복수',
#   '검투사',
#   '로서',
#   '경기',
#   '승리',
#   '명성',
#   '인기',
#   '날로',
#   '간다',
#   '로마',
#   '아내',
#   '아들',
#   '코모',
#   '복수',
#   '다짐',
#   '사랑',
#   '황제',
#   '루실',
#   '닐슨',
#   '민중',
#   '영웅',
#   '막시무스',
#   '코모',
#   '민중',
#   '막시무스',
#   '예전',
#   '부하',
#   '은밀',
#   '사랑',
#   '아내',
#   '아들',
#   '존경',
#   '황제',
#   '살해',
#   '황제',
#   '코모',
#   '복수',
#   '결의',
#   '막시무스',
#   '사랑',
#   '루실',
#   '동생',
#   '코모',
#   '배신',
#   '막시무스',
#   '반란',
#   '도우'],
#  ['대부',
#   '코르',
#   '네오',
#   '마론',
#   '브란',
#   '호화',
#   '저택',
#   '막내딸',
#   '탈리아',
#   '샤이어',
#   '카를로',
#   '지안',
#   '루소',
#   '호화판',
#   '결혼식',
#   '거행',
#   '시실리',
#   '이민',
#   '모진',
#   '고생',
#   '미국',
#   '암흑가',
#   '보스',
#   '군림',
#   '마피아',
#   '두목',
#   '코르',
#   '네오',
#   '재력',
#   '조직',
#   '동원',
#   '갖가지',
#   '고민',
#   '호소',
#   '사람',
#   '문제',
#   '해결',
#   '사람',
#   '대부',
#   '코르',
#   '네오',
#   '고향',
#   '시실리',
#   '가족',
#   '모두',
#   '살해',
#   '오직',
#   '미국',
#   '도피',
#   '밑바닥',
#   '범죄',
#   '세계',
#   '경험',
#   '기반',
#   '다지',
#   '부모',
#   '복수',
#   '시실리',
#   '조직',
#   '범죄',
#   '통해',
#   '비약',
#   '성공',
#   '코르',
#   '네오',
#   '라이벌',
#   '리아',
#   '패밀리',
#   '마약',
#   '밀매',
#   '롯소',
#   '레티',
#   '에리',
#   '코르',
#   '네오',
#   '저격',
#   '중상',
#   '스포일러',
#   '코르',
#   '네오',
#   '막내',
#   '아들',
#   '마이클',
#   '파치노',
#   '대학',
#   '출신',
#   '인텔리',
#   '아버지',
#   '저격',
#   '사건',
#   '계기',
#   '조직',
#   '개입',
#   '레스토랑',
#   '롯소',
#   '사살',
#   '시실리',
#   '피신',
#   '시실리',
#   '시골',
#   '아가씨',
#   '결혼',
#   '추적',
#   '아내',
#   '장남',
#   '소니',
#   '제임스',
#   '자신',
#   '여동생',
#   '학대',
#   '카를로',
#   '앙심',
#   '카를',
#   '자신',
#   '패밀리',
#   '소니',
#   '배반',
#   '이로',
#   '소니',
#   '암살',
#   '코르',
#   '네오',
#   '일가',
#   '붕괴',
#   '직전',
#   '직면',
#   '코르',
#   '네오',
#   '일가',
#   '귀국',
#   '마이클',
#   '대학시절',
#   '애인',
#   '케이',
#   '이안',
#   '재혼',
#   '얼마',
#   '손자',
#   '코르',
#   '오네가',
#   '심장',
#   '발작',
#   '급사',
#   '마이클',
#   '자리',
#   '집안',
#   '양자',
#   '역할',
#   '변호사',
#   '로버트',
#   '듀발',
# ...
#   '도리',
#   '상어',
#   '트리오',
#   '육식',
#   '기계',
#   '오명',
#   '채식',
#   '주의',
#   '상어',
#   '거듭',
#   '나기',
#   '단계',
#   '프로그램',
#   '시작',
#   '매력',
#   '치명',
#   '아귀',
#   '해파리',
#   '지뢰',
#   '거치',
#   '자신',
#   '얼마나',
#   '모험',
#   '감행',
#   '또한',
#   '푸른',
#   '고래',
#   '호주',
#   '동부',
#   '해류',
#   '파도',
#   '돌진',
#   '바다',
#   '거북',
#   '조우',
#   '갈매기',
#   '공격',
#   '가까스로',
#   '시드니',
#   '모험',
#   '전설',
#   '물고기',
#   '콤비',
#   '대해',
#   '아들',
#   '대양',
#   '여행',
#   '영웅',
#   '피쉬',
#   '소문',
#   '니모',
#   '수족관',
#   '니모',
#   '아빠',
#   '자신',
#   '소식',
#   '감격',
#   '격려',
#   '아빠',
#   '열망',
#   '고무',
#   '니모',
#   '과감',
#   '탈출',
#   '계획',
#   '시간',
#   '다음',
#   '니모',
#   '치과의사',
#   '조카딸',
#   '달라',
#   '제물',
#   '판이',
#   '대책',
#   '말괄량이',
#   '달라',
#   '애완',
#   '물고기',
#   '고문',
#   '악명',
#   '시드니',
#   '도착',
#   '도리',
#   '펠리칸',
#   '나이',
#   '도움',
#   '나이',
#   '피쉬',
#   '소문',
#   '시간',
#   '촉각',
#   '바다',
#   '사건',
#   '아빠',
#   '아들',
#   '재회'],
#  ['마담',
#   '유항',
#   '감독',
#   '액션영화',
#   '도전',
#   '가정',
#   '주부',
#   '가족',
#   '교외',
#   '지역',
#   '거주',
#   '전직',
#   '경찰',
#   '그녀',
#   '협박',
#   '그녀',
#   '합의',
#   '과거',
#   '그녀',
#   '그녀',
#   '그녀',
#   '사람',
#   '혼자',
#   '사실',
#   '부산',
#   '국제',
#   '영화제'],
#  ['트랜스포머',
#   '최후',
#   '기사',
#   '옵티머스',
#   '프라임',
#   '이상',
#   '인간',
#   '편이',
#   '트랜스포머',
#   '고향',
#   '사이버',
#   '트론',
#   '재건',
#   '지구',
#   '고대',
#   '유물',
#   '나선',
#   '옵티머스',
#   '프라임',
#   '인류',
#   '갈등',
#   '동료',
#   '범블비',
#   '치명',
#   '대결',
#   '영웅',
#   '하나',
#   '세상',
#   '존재',
#   '다른',
#   '세상'],
#  ['문라이트', '마이애미', '배경', '흑인', '아이', '소년', '청년', '과정', '치명', '사랑', '정체'],
#  ['깡패',
#   '애인',
#   '싸움',
#   '하나',
#   '제대로',
#   '입심',
#   '삼류',
#   '건달',
#   '동철',
#   '박중훈',
#   '예전',
#   '실력',
#   '발휘',
#   '가오',
#   '겉보기',
#   '옆집',
#   '여자',
#   '보고',
#   '전혀',
#   '죽지',
#   '웬걸',
#   '여자',
#   '옆방',
#   '여자',
#   '잔뜩',
#   '바락바락',
#   '여자',
#   '어쩐지',
#   '취업',
#   '전선',
#   '여자',
#   '세진',
#   '정유미',
#   '구한',
#   '반지하',
#   '겉보기',
#   '깡패',
#   '깡패',
#   '옆집',
#   '웬걸',
#   '남자',
#   '옆방',
#   '여자',
#   '꼬박꼬박',
#   '옆집',
#   '깡패',
#   '깡패',
#   '여자',
#   '남녀',
#   '매일',
#   '반지하',
#   '반동',
#   '거가',
#   '시작'],
#  ['마이펫',
#   '이중생활',
#   '시작',
#   '펫들',
#   '시크릿',
#   '라이프',
#   '구석',
#   '걱정',
#   '하루',
#   '맥스',
#   '캣닢',
#   '사랑',
#   '영혼',
#   '클로이',
#   '슈퍼히어로',
#   '토끼',
#   '스노우볼',
#   '고양이',
#   '강아지',
#   '기젯',
#   '마이',
#   '속마음',
#   '공개',
#   '우릴',
#   '생각'],
#  ['고질라',
#   '오브',
#   '몬스터',
#   '고질라',
#   '샌프란시스코',
#   '공격',
#   '아들',
#   '상처',
#   '엠마',
#   '마크',
#   '매디슨',
#   '가족',
#   '슬픔',
#   '미지',
#   '생물',
#   '연구',
#   '나크',
#   '소속',
#   '과학자',
#   '엠마',
#   '다른',
#   '공격',
#   '대비',
#   '거대',
#   '괴수',
#   '소통',
#   '주파수',
#   '발견',
#   '괴수',
#   '조종',
#   '지구',
#   '초토화',
#   '테러',
#   '세력',
#   '매디슨',
#   '납치',
#   '주파수',
#   '모스',
#   '로단',
#   '기도',
#   '고대',
#   '괴수',
#   '하나',
#   '역대',
#   '재난',
#   '상황',
#   '인류',
#   '생존',
#   '자체',
#   '여기',
#   '고질라',
#   '등장',
#   '괴수',
#   '대결',
#   '국면',
#   '맞이',
#   '최악',
#   '위기',
#   '가족',
#   '위험'],
#  ['불한당',
#   '세상',
#   '범죄',
#   '조직',
#   '인자',
#   '재호',
#   '세상',
#   '패기',
#   '신참',
#   '현수',
#   '교도소',
#   '서로',
#   '끈끈',
#   '의리',
#   '간다',
#   '권력',
#   '차지',
#   '의기',
#   '투합',
#   '사람',
#   '야망',
#   '서로',
#   '대해',
#   '사실',
#   '관계',
#   '시작',
#   '조심',
#   '하라',
#   '믿음',
#   '순간',
#   '배신',
#   '시작'],
#  ['가족',
#   '황정민',
#   '마다',
#   '라면',
#   '비교',
#   '정의',
#   '변호사',
#   '아내',
#   '호정',
#   '문소리',
#   '전직',
#   '무용수',
#   '현재',
#   '동네',
#   '무용',
#   '학원',
#   '전부',
#   '주부',
#   '모범',
#   '변호사',
#   '가장이',
#   '희망',
#   '호정',
#   '부부',
#   '입양',
#   '아들',
#   '수인',
#   '가족',
#   '부부',
#   '아들',
#   '무척',
#   '사랑',
#   '아들',
#   '수인',
#   '요즘',
#   '자신',
#   '입양아',
#   '사실',
#   '때문',
#   '혼란',
#   '겉보기',
#   '남편',
#   '호정',
#   '섹스',
#   '이상',
#   '오르가즘',
#   '남편',
#   '축해',
#   '아버지',
#   '김인문',
#   '가족',
#   '기억',
#   '평생',
#   '의존',
#   '중증',
#   '알코올',
#   '중독',
#   '자로',
#   '간암',
#   '말기',
#   '선고',
#   '아내',
#   '윤여정',
#   '섹스',
#   '나이',
#   '애인',
#   '바람',
#   '나이',
#   '관계',
#   '그녀',
#   '정신',
#   '육체',
#   '상위',
#   '섹스',
#   '모든',
#   '요구',
#   '실행',
#   '호정',
#   '머리',
#   '옆집',
#   '고삐',
#   '봉태규',
#   '바람',
#   '언제',
#   '끈끈',
#   '눈길',
#   '연애',
#   '하자',
#   '노골',
#   '제안',
#   '호기심',
#   '열망',
#   '입곱살',
#   '소년',
#   '맹랑',
#   '대쉬',
#   '제법',
#   '호정',
#   '자극',
#   '그녀',
#   '구멍',
#   '고삐',
#   '주기',
#   '호정',
#   '시어머니',
#   '초등학교',
#   '동창',
#   '바람',
#   '술병',
#   '남편',
#   '섹스',
#   '평생',
#   '오르가즘',
#   '그녀',
#   '마나도',
#   '애인',
#   '섹스',
#   '새삼',
#   '살맛',
#   '게다가',
#   '오르가즘',
#   '인생',
#   '자신',
#   '육체',
#   '감정',
#   '모두',
#   '살기',
#   '그녀',
#   '자기',
#   '인생',
#   '주인',
#   '구석',
#   '대체',
#   '간암',
#   '병원',
#   '입원',
#   '아내',
#   '자식',
#   '초등학교',
#   '동창',
#   '애인',
#   '결혼',
#   '충격',
#   '선언',
#   '시어머니',
#   '고백',
#   '며느리',
#   '호정',
#   '응원',
#   '아들',
#   '코방귀',
#   '뀐다',
#   '시어머니',
#   '남편',
#   '죽음',
#   '출장',
#   '간다',
#   '핑계',
#   '애인',
#   '여행',
#   '취한',
#   '오토바이',
#   '몰던',
#   '지루',
#   '성지루',
#   '교통사고',
#   '잘못',
#   '바람',
#   '지루',
#   '어처구니',
#   '아들',
#   '수인',
#   '아들',
#   '수인',
#   '죽음',
#   '충격',
#   '호정',
#   '서로',
#   '바람',
#   '미로',
#   '다툼',
#   '호정',
#   '병원',
#   '간다',
#   '호정',
#   '치료',
#   '서로',
#   '다른',
#   '방향',
#   '택시',
#   '각자',
#   '애인',
#   '애인',
#   '그녀',
#   '애인',
#   '이중',
#   '위기',
#   '아내',
#   '애인',
#   '아들',
#   '수인',
#   '대신',
#   '옆집',
#   '고삐',
#   '아이',
#   '임신',
#   '호정',
#   '남편',
#   '아이',
#   '누구',
#   '포기',
#   '결정'],
#  ['뷰티풀',
#   '모먼트',
#   '벚꽃',
#   '승준',
#   '운명',
#   '사람',
#   '다음',
#   '약속',
#   '승준',
#   '거짓말',
#   '승준',
#   '비밀',
#   '바로',
#   '이의',
#   '시간',
#   '다른',
#   '사람',
#   '벚꽃',
#   '순간',
#   '오기',
#   '하루',
#   '승준',
#   '계절',
#   '서로',
#   '만날',
#   '지구',
#   '시간',
#   '사랑',
#   '계속'],
#  ['나비',
#   '효과',
#   '나비',
#   '날개',
#   '지구',
#   '반대편',
#   '태풍',
#   '수도',
#   '카오스',
#   '이론',
#   '시절',
#   '상처',
#   '에반',
#   '기억',
#   '파편',
#   '상처',
#   '친구',
#   '에반',
#   '과거',
#   '기억',
#   '정신과',
#   '치료',
#   '매일',
#   '일기',
#   '대학생',
#   '예전',
#   '일기',
#   '일기장',
#   '통해',
#   '시공간',
#   '이동',
#   '통로',
#   '발견',
#   '에반',
#   '그것',
#   '통해',
#   '과거',
#   '기억',
#   '시절',
#   '상처',
#   '때문',
#   '스스로',
#   '목숨',
#   '첫사랑',
#   '켈리',
#   '과거',
#   '사랑',
#   '친구',
#   '불행',
#   '과거',
#   '더욱',
#   '충격',
#   '현실',
#   '현재',
#   '전혀',
#   '상치',
#   '파국',
#   '과거',
#   '현재',
#   '현재'],
#  ['연애담',
#   '미술',
#   '공부',
#   '윤주',
#   '이상희',
#   '졸업',
#   '전시',
#   '준비',
#   '자꾸',
#   '눈길',
#   '사람',
#   '살짝',
#   '눈빛',
#   '윤주',
#   '마음',
#   '리기',
#   '시작',
#   '아르바이트',
#   '지수',
#   '류선영',
#   '겨울',
#   '사람',
#   '얼마',
#   '사람',
#   '만난',
#   '지수',
#   '사람',
#   '마음',
#   '사람',
#   '마음',
#   '이어진',
#   '가장',
#   '순간',
#   '정말'],
#  ['괴물',
#   '햇살',
#   '한강',
#   '아버지',
#   '변희봉',
#   '운영',
#   '한강',
#   '매점',
#   '낮잠',
#   '강두',
#   '송강호',
#   '잠결',
#   '아빠',
#   '소리',
#   '벌떡',
#   '일어난다',
#   '올해',
#   '중학생',
#   '고아성',
#   '잔뜩',
#   '화가',
#   '기도',
#   '핸드폰',
#   '학부모',
#   '참관',
#   '수업',
#   '냄새',
#   '풍기',
#   '삼촌',
#   '박해일',
#   '때문',
#   '강두',
#   '고민',
#   '비밀리',
#   '동전',
#   '가득',
#   '컵라면',
#   '그릇',
#   '시작',
#   '고모',
#   '배두나',
#   '전국체전',
#   '양궁',
#   '경기',
#   '괴물',
#   '한강',
#   '오징어',
#   '배달',
#   '강두',
#   '성웅',
#   '사람',
#   '광경',
#   '목격',
#   '생전',
#   '보도',
#   '무언가',
#   '한강',
#   '다리',
#   '사람',
#   '마냥',
#   '핸드폰',
#   '디카',
#   '정신',
#   '그것',
#   '잠시',
#   '정체',
#   '괴물',
#   '위로',
#   '사람',
#   '무차별',
#   '물어',
#   '시작',
#   '순식간',
#   '아수라',
#   '돌변',
#   '강변',
#   '강두',
#   '데리',
#   '정신',
#   '비명',
#   '사람',
#   '순간',
#   '괴물',
#   '듯이',
#   '유유',
#   '한강',
#   '어딘가',
#   '반드시',
#   '괴물',
#   '출현',
#   '한강',
#   '모두',
#   '폐쇄되',
#   '도시',
#   '전체',
#   '마비',
#   '하루아침',
#   '생계',
#   '가장',
#   '모든',
#   '강두',
#   '가족',
#   '아무',
#   '위험',
#   '구역',
#   '선포',
#   '한강',
#   '어딘가'],
#  ['에스',
#   '인의',
#   '에이지',
#   '에이미',
#   '맥스',
#   '도미니크',
#   '자넷',
#   '살인',
#   '음모',
#   '사격',
#   '격투',
#   '재질',
#   '젊은이',
#   '훈련',
#   '비밀',
#   '조직',
#   '뎁스',
#   '우수',
#   '학생',
#   '뎁스',
#   '최고',
#   '라이벌',
#   '레놀즈',
#   '범죄',
#   '조직',
#   '여자',
#   '두목',
#   '루시',
#   '다이아몬드',
#   '체포하라',
#   '임무',
#   '루시',
#   '여자',
#   '암살자',
#   '식당',
#   '첩보',
#   '입수',
#   '뎁스',
#   '현장',
#   '급파',
#   '한바탕',
#   '총격',
#   '전과',
#   '격전',
#   '서로',
#   '가슴',
#   '겨누',
#   '루시',
#   '에이미',
#   '사이',
#   '감정',
#   '루시',
#   '부하',
#   '스커드',
#   '자넷',
#   '역시',
#   '상치',
#   '관계'],
#  ['리틀',
#   '보이',
#   '이상',
#   '때문',
#   '리틀',
#   '보이',
#   '페퍼',
#   '친구',
#   '로부터',
#   '놀림',
#   '일쑤',
#   '전쟁',
#   '하나',
#   '친구',
#   '아빠',
#   '마술',
#   '페퍼',
#   '오른',
#   '무대',
#   '물건',
#   '능력',
#   '발견',
#   '능력',
#   '전쟁',
#   '아빠',
#   '페퍼',
#   '자신',
#   '능력',
#   '믿음',
#   '지진',
#   '자신',
#   '동네',
#   '사람',
#   '깜짝',
#   '페퍼',
#   '전쟁'],
#  ['이웃집',
#   '토토',
#   '도시',
#   '시골',
#   '이사',
#   '사츠키',
#   '메이',
#   '숲속',
#   '생명체',
#   '토토',
#   '모험',
#   '어머니',
#   '병원',
#   '위태',
#   '소식',
#   '도착',
#   '언니',
#   '사츠키',
#   '아빠',
#   '연락',
#   '취하',
#   '와중',
#   '메이',
#   '행방불명'],
#  ['파수',
#   '소년',
#   '평소',
#   '아들',
#   '소년',
#   '아버지',
#   '조성하',
#   '아들',
#   '공백',
#   '매우',
#   '혼란',
#   '죄책감',
#   '아들',
#   '기태',
#   '이제훈',
#   '죽음',
#   '시작',
#   '아들',
#   '책상',
#   '서랍',
#   '보관',
#   '사진',
#   '동윤',
#   '서준영',
#   '박정민',
#   '학교',
#   '겨우',
#   '사실',
#   '아이',
#   '전학',
#   '아이',
#   '장례식',
#   '오지',
#   '뭔가',
#   '기태',
#   '제일',
#   '동윤',
#   '대답',
#   '회피',
#   '아버지',
#   '부탁',
#   '동윤',
#   '나선',
#   '학교',
#   '자퇴',
#   '친구',
#   '어디',
#   '시절',
#   '소통',
#   '오해',
#   '비극',
#   '파국',
#   '독단',
#   '우정',
#   '폭력',
#   '상처',
#   '전염',
#   '우리',
#   '충격',
#   '결말',
#   '간다',
#   '서로',
#   '전부',
#   '친구',
#   '사이',
#   '무슨'],
#  ['패딩턴',
#   '폭풍우',
#   '가족',
#   '꼬마',
#   '패딩턴',
#   '페루',
#   '영국',
#   '홀로',
#   '여행',
#   '런던',
#   '도착',
#   '패딩턴',
#   '브라운',
#   '가족',
#   '도움',
#   '가족',
#   '해도',
#   '사고',
#   '해도',
#   '사고',
#   '한번',
#   '사고',
#   '패딩턴',
#   '브라운',
#   '가족',
#   '골칫거리',
#   '소식',
#   '악당',
#   '박제',
#   '밀리',
#   '센트',
#   '호시탐탐',
#   '패딩턴'],
#  ['트랜센던스',
#   '인류',
#   '지적',
#   '능력',
#   '초월',
#   '자각',
#   '능력',
#   '슈퍼',
#   '트랜센던스',
#   '완성',
#   '목전',
#   '천재',
#   '과학자',
#   '조니',
#   '기술',
#   '발전',
#   '인류',
#   '멸망',
#   '주장',
#   '과학',
#   '단체',
#   '공격',
#   '목숨',
#   '연인',
#   '에블린',
#   '레베카',
#   '컴퓨터',
#   '업로드',
#   '다른',
#   '온라인',
#   '접속',
#   '자신',
#   '영역',
#   '세계',
#   '시작'],
#  ['귀멸',
#   '칼날',
#   '아사쿠사',
#   '살대',
#   '입대',
#   '탄지',
#   '매일',
#   '소녀',
#   '실종',
#   '마을',
#   '귀의',
#   '냄새',
#   '모습',
#   '가운데',
#   '소녀',
#   '귀의',
#   '그다음',
#   '탄지',
#   '방문',
#   '아사쿠사',
#   '도시',
#   '상점',
#   '당황',
#   '탄지',
#   '귀의',
#   '냄새',
#   '냄새',
#   '인간',
#   '귀로',
#   '존재',
#   '탄지',
#   '숙적',
#   '키부츠',
#   '무잔',
#   '이윽고',
#   '탄지',
#   '타마요',
#   '시로'],
#  ['킹스',
#   '시크릿',
#   '에이전트',
#   '세상',
#   '가장',
#   '면접',
#   '시작',
#   '주니어',
#   '체조',
#   '대회',
#   '연속',
#   '우승',
#   '학교',
#   '중퇴',
#   '해병대',
#   '중도',
#   '하차',
#   '동네',
#   '패싸움',
#   '직장',
#   '적도',
#   '볼일',
#   '루저',
#   '낙인',
#   '젠틀맨',
#   '스파이',
#   '전격',
#   '스카우트',
#   '전설',
#   '베테',
#   '요원',
#   '하트',
#   '콜린',
#   '퍼스',
#   '경찰서',
#   '구치',
#   '태런',
#   '애거',
#   '제한',
#   '잠재력',
#   '전설',
#   '국제',
#   '비밀',
#   '정보',
#   '기구',
#   '킹스',
#   '면접',
#   '참여',
#   '아버지',
#   '또한',
#   '킹스',
#   '촉망',
#   '요원',
#   '하트',
#   '사실',
#   '목숨',
#   '만큼',
#   '위험천만',
#   '훈련',
#   '통과',
#   '킹스',
#   '후보',
#   '최종',
#   '멤버',
#   '발탁',
#   '최고',
#   '악당',
#   '발렌타인',
#   '사무엘',
#   '잭슨',
#   '마주',
#   '엑스맨',
#   '퍼스트',
#   '클래스',
#   '감독',
#   '마블',
#   '코믹스',
#   '인기',
#   '작가',
#   '만남',
#   '스파이',
#   '액션',
#   '시대',
#   '린다'],
#  ['미션',
#   '세기',
#   '극단',
#   '시대',
#   '원주민',
#   '과라니족',
#   '마을',
#   '선교',
#   '활동',
#   '가브리엘',
#   '신부',
#   '살인',
#   '복역',
#   '포르투갈',
#   '영토',
#   '편입',
#   '죽음',
#   '위기',
#   '원주민',
#   '목격',
#   '무력',
#   '비폭력',
#   '서로',
#   '다른',
#   '선택',
#   '감행',
#   '사람',
#   '사람'],
#  ['파파로티',
#   '성악',
#   '천재',
#   '건달',
#   '형님',
#   '적수',
#   '성악가',
#   '지금',
#   '구석',
#   '예고',
#   '음악',
#   '선생',
#   '상진',
#   '한석규',
#   '교육',
#   '충만',
#   '청천벽력',
#   '미션',
#   '부적',
#   '노래',
#   '실력',
#   '일찍이',
#   '주먹',
#   '세계',
#   '입문',
#   '건달',
#   '장호',
#   '이제훈',
#   '콩쿨',
#   '입상',
#   '하라',
#   '전학',
#   '첫날',
#   '승용차',
#   '어깨',
#   '대동',
#   '모자라',
#   '수업',
#   '형님',
#   '전화',
#   '무늬',
#   '학생',
#   '장호',
#   '상진',
#   '장호',
#   '노래',
#   '필요',
#   '결론',
#   '린다',
#   '된장',
#   '주먹',
#   '노래',
#   '가지',
#   '재능',
#   '가정',
#   '환경',
#   '주먹',
#   '세계',
#   '장호',
#   '비록',
#   '현실',
#   '파바로티',
#   '이름',
#   '하나',
#   '제대로',
#   '건달',
#   '성악가',
#   '자신',
#   '툭하면',
#   '소나',
#   '취미',
#   '클래식',
#   '사사건건',
#   '무시',
#   '상진',
#   '태도',
#   '발끈',
#   '장호',
#   '포기',
#   '장호',
#   '상진',
#   '관계'],
#  ['마지막',
#   '걸음',
#   '작품',
#   '대전',
#   '당시',
#   '소련군',
#   '포로',
#   '세월',
#   '지난',
#   '비로소',
#   '가족',
#   '클레멘스',
#   '포렐',
#   '실화',
#   '영화로',
#   '대전',
#   '당시',
#   '소련군',
#   '포로',
#   '포렐',
#   '강제노동',
#   '용소',
#   '탈출',
#   '고국',
#   '탈출',
#   '과정',
#   '순탄',
#   '용소',
#   '소장',
#   '카마',
#   '네프',
#   '도중',
#   '만난',
#   '사람',
#   '위협',
#   '스파이',
#   '혐의',
#   '포렐',
#   '탈출',
#   '과정',
#   '소설',
#   '출판',
#   '이전',
#   '영화',
#   '작품',
#   '시베리아',
#   '중앙',
#   '아시아',
#   '지난',
#   '포렐',
#   '탈출',
#   '과정',
#   '자유',
#   '의지',
#   '신념',
#   '초점',
#   '무엇',
#   '시베리아',
#   '중앙',
#   '아시아',
#   '포렐',
#   '카마',
#   '네프',
#   '추격',
#   '전도',
#   '흥미',
#   '러닝',
#   '타임',
#   '최근',
#   '장가',
#   '대작',
#   '영화',
#   '부천',
#   '판타스틱',
#   '영화제',
#   '소개',
#   '자료',
#   '인용'],
#  ['메이즈',
#   '러너',
#   '삭제',
#   '기억',
#   '미로',
#   '낯선',
#   '공간',
#   '모든',
#   '기억',
#   '삭제',
#   '의문',
#   '장소',
#   '토마스',
#   '딜런',
#   '브라이언',
#   '토마스',
#   '미로',
#   '자신',
#   '상황',
#   '사람',
#   '매일',
#   '미로',
#   '정체',
#   '죽음',
#   '존재',
#   '대립',
#   '지옥',
#   '탈출',
#   '구인',
#   '지도',
#   '완성',
#   '미로',
#   '마지막',
#   '선택',
#   '순간',
#   '예측',
#   '미로',
#   '탈출'],
#  ['여인',
#   '향기',
#   '퇴역',
#   '장교',
#   '프랭크',
#   '레드',
#   '파치노',
#   '맹인',
#   '시적',
#   '분위기',
#   '철학',
#   '면모',
#   '성격',
#   '진실',
#   '소유',
#   '사랑',
#   '맹인',
#   '퇴역',
#   '장교',
#   '사촌',
#   '슬레드',
#   '제외',
#   '가족',
#   '추수감사절',
#   '여행',
#   '찰리',
#   '심스',
#   '크리스',
#   '오도',
#   '하버드',
#   '대학',
#   '목표',
#   '예비',
#   '학교',
#   '장학생',
#   '모범',
#   '학생',
#   '찰리',
#   '생각',
#   '뉴욕',
#   '비행기',
#   '슬레드',
#   '인생',
#   '교육',
#   '시작',
#   '최고급',
#   '호텔',
#   '식당',
#   '리무진',
#   '사이',
#   '오가면',
#   '성격',
#   '슬레드',
#   '작업',
#   '시작',
#   '찰리',
#   '경험',
#   '여자',
#   '모든',
#   '초능력',
#   '고독감',
#   '죽음',
#   '유혹',
#   '찰리',
#   '인생',
#   '의미',
#   '부여',
#   '슬레',
#   '중령',
#   '정복',
#   '방아쇠',
#   '당신',
#   '인생',
#   '인생',
#   '인생',
#   '어둠',
#   '당신',
#   '탱고',
#   '스포츠카',
#   '사람',
#   '경험',
#   '찰리',
#   '아주',
#   '과정',
#   '찰리',
#   '슬레',
#   '서로',
#   '슬레',
#   '찰리',
#   '인생',
#   '한번',
#   '지게',
#   '뉴욕',
#   '여행',
#   '마을',
#   '슬레',
#   '찰리',
#   '아버지',
#   '자격',
#   '찰리',
#   '학교',
#   '교장',
#   '요구',
#   '처우',
#   '대항',
#   '한판',
#   '학생',
#   '로부터',
#   '박수',
#   '찰리',
#   '명예롭',
#   '퇴장',
#   '찰리',
#   '슬레드',
#   '집앞',
#   '마중',
#   '슬레드',
#   '조카',
#   '다정',
#   '담소',
#   '안심',
#   '자기',
#   '가게'],
#  ['보이스',
#   '부산',
#   '건설',
#   '현장',
#   '직원',
#   '상대로',
#   '전화',
#   '보이스피싱',
#   '전화',
#   '병원',
#   '아파트',
#   '중도',
#   '당일',
#   '현장',
#   '사람',
#   '목숨',
#   '현장',
#   '작업',
#   '장인',
#   '전직',
#   '형사',
#   '서준',
#   '요한',
#   '가족',
#   '동료',
#   '보이스피싱',
#   '조직',
#   '추적',
#   '시작',
#   '마침내',
#   '중국',
#   '위치',
#   '거지',
#   '콜센터',
#   '잠입',
#   '서준',
#   '개인정보',
#   '확보',
#   '기획',
#   '대본',
#   '섭외',
#   '환전소',
#   '작업',
#   '대규모',
#   '콜센터',
#   '체계',
#   '조직',
#   '보이스피싱',
#   '스케일',
#   '피해자',
#   '희망',
#   '공포',
#   '목소리',
#   '주인공',
#   '기획',
#   '곽프',
#   '김무열',
#   '마주',
#   '규모',
#   '총력전',
#   '기획',
#   '상상',
#   '이상',
#   '조직',
#   '보이스피싱',
#   '실체',
#   '반드시'],
#  ['더독',
#   '하루아침',
#   '운명',
#   '강아지',
#   '뭉치',
#   '만난',
#   '거리',
#   '생활',
#   '고참',
#   '짱아',
#   '일당',
#   '목숨',
#   '짱아',
#   '무리',
#   '스트릿',
#   '라이프',
#   '찰나',
#   '아지트',
#   '위기',
#   '마침내',
#   '자유',
#   '찾기',
#   '모험',
#   '결심'],
#  ['한니발',
#   '요원',
#   '클라리스',
#   '스탈',
#   '싸이코',
#   '살인마',
#   '한니발',
#   '렉터',
#   '박사',
#   '도움',
#   '납치',
#   '상원의원',
#   '명성',
#   '사건',
#   '이후',
#   '그녀',
#   '주목',
#   '오히려',
#   '원칙',
#   '골치',
#   '거리',
#   '마약',
#   '소굴',
#   '소탕',
#   '작전',
#   '진행',
#   '과정',
#   '아기',
#   '안고',
#   '마약',
#   '사범',
#   '그로',
#   '언론',
#   '질책',
#   '그녀',
#   '좌천',
#   '위기',
#   '재력',
#   '가로',
#   '한니발',
#   '달라',
#   '제의',
#   '한니발',
#   '희생',
#   '메이슨',
#   '한니발',
#   '잡기',
#   '스탈',
#   '미끼',
#   '이용',
#   '스탈',
#   '계획',
#   '한니발',
#   '찾기',
#   '전력',
#   '한니발',
#   '은둔',
#   '생활',
#   '스탈',
#   '재회',
#   '미국',
#   '한니발',
#   '메이슨',
#   '법무성',
#   '간부',
#   '고용',
#   '자신',
#   '살해',
#   '차례대로',
#   '복수'],
#  ['배드',
#   '가이즈',
#   '작전',
#   '설계',
#   '금고',
#   '해제',
#   '해킹',
#   '액션',
#   '위장',
#   '플레이',
#   '자타공인',
#   '최고',
#   '녀석',
#   '한순간',
#   '실수',
#   '체포',
#   '마멀레이드',
#   '박사',
#   '주장',
#   '녀석',
#   '생활',
#   '프로젝트',
#   '투입',
#   '한번',
#   '자유',
#   '처음',
#   '생활',
#   '도전',
#   '녀석',
#   '사상',
#   '초유',
#   '생활',
#   '프로젝트',
#   '시작'],
#  ['극장판',
#   '검정',
#   '고무신',
#   '기철',
#   '인생',
#   '최대',
#   '위기',
#   '짝사랑',
#   '여학생',
#   '수업료',
#   '모두',
#   '기철',
#   '생애',
#   '아르바이트',
#   '시작',
#   '서울',
#   '기철',
#   '온갖',
#   '우여곡절',
#   '말리',
#   '기철'],
#  ['애프터',
#   '사랑',
#   '경험',
#   '애프터',
#   '대학',
#   '입학',
#   '파티',
#   '초대',
#   '신입생',
#   '테사',
#   '진실게임',
#   '키스',
#   '벌칙',
#   '상대',
#   '학교',
#   '반항',
#   '하딘',
#   '키스',
#   '모두',
#   '주목',
#   '순간',
#   '테사',
#   '하딘',
#   '입술',
#   '거절',
#   '만남',
#   '이후',
#   '마치',
#   '세상',
#   '발견',
#   '한번',
#   '경험',
#   '감정',
#   '사람',
#   '하딘',
#   '자신',
#   '비밀',
#   '장소',
#   '테사',
#   '초대',
#   '사람',
#   '서로',
#   '절대'],
#  ['피아니스트',
#   '전설',
#   '유럽',
#   '미국',
#   '버지니아',
#   '평생',
#   '바다',
#   '천재',
#   '피아니스트',
#   '나인',
#   '드레드',
#   '친구',
#   '트럼펫',
#   '연주자',
#   '맥스',
#   '첫사랑',
#   '마지막',
#   '사랑',
#   '소문',
#   '재즈',
#   '피아니스트',
#   '바다',
#   '세상',
#   '인생',
#   '변화'],
#  ['킬러',
#   '도시',
#   '대주교',
#   '암살',
#   '영국',
#   '킬러',
#   '레이',
#   '콜린',
#   '파렐',
#   '브레단',
#   '리스',
#   '보스',
#   '동안',
#   '벨기에',
#   '관광',
#   '도시',
#   '브리',
#   '주로',
#   '가라',
#   '명령',
#   '린다',
#   '브리',
#   '세풍',
#   '관광',
#   '도시',
#   '낙천',
#   '넘버',
#   '킬러',
#   '관광',
#   '혈기',
#   '왕성',
#   '레이',
#   '레이',
#   '거리',
#   '만난',
#   '매력',
#   '여인',
#   '사랑',
#   '브리',
#   '주의',
#   '시간',
#   '그때',
#   '킬러',
#   '보스',
#   '헤리',
#   '랄프',
#   '인즈',
#   '명령',
#   '린다',
#   '그것',
#   '바로',
#   '대주교',
#   '암살',
#   '킬러',
#   '규칙',
#   '실수',
#   '레이',
#   '그때',
#   '도시',
#   '브리',
#   '킬러',
#   '마지막',
#   '대결',
#   '장소'],
#  ['주먹',
#   '랄프',
#   '패키지',
#   '자막',
#   '더빙',
#   '비트',
#   '게임',
#   '펠릭스',
#   '건물',
#   '부수',
#   '악당',
#   '주먹',
#   '랄프',
#   '매일',
#   '건물',
#   '부수',
#   '직업',
#   '충실',
#   '악당',
#   '이유',
#   '누구',
#   '모두',
#   '인정',
#   '영웅',
#   '마음',
#   '자기',
#   '게임',
#   '이탈',
#   '다른',
#   '게임',
#   '랄프',
#   '슈팅게임',
#   '히어로즈',
#   '듀티',
#   '레이싱',
#   '게임',
#   '슈가',
#   '러시',
#   '불시',
#   '랄프',
#   '게임',
#   '세계',
#   '영웅',
#   '랄프',
#   '고장',
#   '딱지',
#   '펠릭스',
#   '게임',
#   '오락실',
#   '위기'],
#  ['그랜',
#   '토리노',
#   '자동차',
#   '공장',
#   '은퇴',
#   '무료',
#   '일상',
#   '월트',
#   '클린트',
#   '이스트',
#   '우드',
#   '국전',
#   '참전',
#   '상처',
#   '남편',
#   '참회',
#   '아내',
#   '유언',
#   '불구',
#   '참회',
#   '이웃집',
#   '소년',
#   '타오',
#   '갱단',
#   '협박',
#   '월트',
#   '그랜',
#   '토리노',
#   '만남',
#   '차고',
#   '기만',
#   '자신',
#   '자동차',
#   '그랜',
#   '토리노',
#   '전쟁',
#   '이후',
#   '자신',
#   '진심',
#   '시작'],
#  ...]

# %%
df['명사'] = total
df
# Out:
#                                 제목    평점        감독  \
# 0                            범죄도시3   7.6       이상용
# 1     엘리멘탈(패키지: 자막판+더빙판+부가영상+코멘터리)   9.4      피터 손
# 2                       공조2: 인터내셔날   8.3       이석훈
# 3               아바타: 물의 길(부가영상 제공)   8.6   제임스 카메론
# 4                              올빼미   9.3       안태진
# ...                            ...   ...       ...
# 5191                    트론: 새로운 시작   7.3   조셉 코신스키
# 5192                리버티 벨런스를 쏜 사나이   8.4      존 포드
# 5193                         리썰 웨폰   8.3    리차드 도너
# 5194                     몽골리안 프린세스   7.5       정단우
# 5195            안녕자두야 스페셜 : 언더 더 씨  10.0       손석우
#
#                                                      배우  \
# 0          마동석 이준혁 아오키 무네타카 이범수 김민재 이지훈 김도건 고규필 전석호 안세호
# 1                                         레아 루이스 마무두 아티
# 2               현빈 유해진 윤아 다니엘 헤니 진선규 장영남 박훈 임성재 윤상화 박민하
# 3      조 샐다나 샘 워싱턴 시고니 위버 우나 채플린 지오바니 리비시 스티븐 랭 케이트 ...
# 4               류준열 유해진 최무성 조성하 박명훈 김성철 안은진 조윤서 이주원 김예은
# ...                                                 ...
# 5191   제프 브리지스 가렛 헤드룬드 올리비아 와일드 마이클 쉰 애니스 처파 브루스 박스라...
# 5192   존 웨인 제임스 스튜어트 베라 마일즈 리 마빈 에드먼드 오브라이언 앤디 데빈 켄 ...
# 5193               멜 깁슨 대니 글로버 게리 부시 미치 라이언 톰 앳킨스 달린 러브
# 5194                                 정단우 엘리자베스 가르시아 박하나
# 5195            여민정 양정화 정유미 김현지 최준영 정혜옥 김보영 김영은 정혜원 김새해
#
#                                                    개봉일자  \
# 0                                           2023.05.31.
# 1                                           2023.06.14.
# 2                                           2022.09.07.
# 3                                           2022.12.14.
# 4                                           2022.11.23.
# ...                                                 ...
# 5191                                        2010.12.29.
# 5192  주연 존 웨인 제임스 스튜어트 베라 마일즈 리 마빈 에드먼드 오브라이언 앤디 데빈 ...
# 5193                                        1987.12.01.
# 5194                                        2015.03.19.
# 5195         주연 여민정 양정화 정유미 김현지 최준영 정혜옥 김보영 김영은 정혜원 김새해
#
#                                                     줄거리  \
# 0     대체불가 괴물형사 마석도 서울 광수대로 발탁! 베트남 납치 살해범 검거 후 7년 뒤...
# 1     불 물 공기 흙 4개의 원소들이 살고 있는 ‘엘리멘트 시티’ 재치 있고 불처럼 열정...
# 2     공조 이즈 백! 이번엔 삼각 공조다!남한으로 숨어든 글로벌 범죄 조직을 잡기 위해 ...
# 3     <아바타: 물의 길>은 판도라 행성에서 '제이크 설리'와 '네이티리'가 이룬 가족이...
# 4     맹인이지만 뛰어난 침술 실력을 지닌 ‘경수’는어의 ‘이형익’에게 그 재주를 인정받아...
# ...                                                 ...
# 5191  세상 누구도 본적 없는 최고의 가상 현실을 창조한 천재박사 케빈 플린(제프 브리지스...
# 5192  랜스(제임스 스튜어트 분)는 자신의 오래전 친구 톰(존 웨인 분)의 장례식에 참석하...
# 5193  술집 여종업원인 아멘다 훤세커(Amanda Hunsaker: 잭키 스완슨 분)가 약...
# 5194  34살이 되도록 연애 한번 못해보고 영화밖에 모르고 살아온 ‘단우’. 어느 날 본인...
# 5195  안녕 자두야 스페셜 언더 더 씨! 바다에서 펼쳐지는 자두의 세가지 이야기. 하나 별...
#
#                                                      내용  감성점수 감성분석결과  \
# 0     범죄도시3 대체불가 괴물형사 마석도 서울 광수대로 발탁! 베트남 납치 살해범 검거 ...   -14     부정
# 1     엘리멘탈(패키지: 자막판+더빙판+부가영상+코멘터리) 불 물 공기 흙 4개의 원소들이...     9     긍정
# 2     공조2: 인터내셔날 공조 이즈 백! 이번엔 삼각 공조다!남한으로 숨어든 글로벌 범죄...   -19     부정
# 3     아바타: 물의 길(부가영상 제공) <아바타: 물의 길>은 판도라 행성에서 '제이크 ...    -5     부정
# 4     올빼미 맹인이지만 뛰어난 침술 실력을 지닌 ‘경수’는어의 ‘이형익’에게 그 재주를 ...   -12     부정
# ...                                                 ...   ...    ...
# 5191  트론: 새로운 시작 세상 누구도 본적 없는 최고의 가상 현실을 창조한 천재박사 케빈...     9     긍정
# 5192  리버티 벨런스를 쏜 사나이 랜스(제임스 스튜어트 분)는 자신의 오래전 친구 톰(존 ...    -8     부정
# 5193  리썰 웨폰 술집 여종업원인 아멘다 훤세커(Amanda Hunsaker: 잭키 스완슨...   -24     부정
# 5194  몽골리안 프린세스 34살이 되도록 연애 한번 못해보고 영화밖에 모르고 살아온 ‘단우...    -8     부정
# 5195  안녕자두야 스페셜 : 언더 더 씨 안녕 자두야 스페셜 언더 더 씨! 바다에서 펼쳐지...     2     긍정
#
#                                                      명사
# 0     [범죄, 도시, 대체, 불가, 괴물, 형사, 석도, 서울, 광수, 발탁, 베트남, ...
# 1     [엘리, 멘탈, 패키지, 자막, 더빙, 부가, 영상, 터리, 공기, 원소, 엘리, ...
# 2     [공조, 인터, 공조, 이즈, 이번, 삼각, 공조, 남한, 글로벌, 범죄, 조직, ...
# 3     [아바타, 물의, 부가, 영상, 제공, 아바타, 물의, 판도라, 행성, 제이크, 설...
# 4     [올빼미, 맹인, 침술, 실력, 경수, 이형, 재주, 무렵, 인질, 소현세자, 귀국...
# ...                                                 ...
# 5191  [트론, 시작, 세상, 누구, 본적, 최고, 가상, 현실, 창조, 천재, 박사, 케...
# 5192  [리버티, 벨런스, 사나이, 랜스, 제임스, 스튜어트, 자신, 친구, 웨인, 장례식...
# 5193  [웨폰, 술집, 종업원, 아멘, 훤세커, 잭키, 스완슨, 복용, 호텔, 아래, 사건...
# 5194  [몽골리안, 프린세스, 살이, 연애, 한번, 영화, 단우, 본인, 주연, 영화, 시...
# 5195  [안녕, 자두, 스페셜, 안녕, 자두, 스페셜, 바다, 자두, 가지, 하나, 주부,...
#
# [5195 rows x 10 columns]

# %% [markdown]
# # 영화 인기순위 1000위까지의 단어 빈도분석

# %%
df.drop(index=1298, inplace=True)
# Out:
# 제목                                                     레드슈즈
# 평점                                                      9.2
# 감독                                                      홍성호
# 배우         클로이 모레츠 샘 클라플린 지나 거손 패트릭 와버튼 짐 러쉬 프레더릭 하멜 아바 ...
# 개봉일자                                            2019.07.25.
# 줄거리       사건 사고가 끊이지 않는 동화의 섬. 사라진 아빠를 찾던 화이트 왕국의 공주는우연히...
# 내용        레드슈즈 사건 사고가 끊이지 않는 동화의 섬. 사라진 아빠를 찾던 화이트 왕국의 공...
# 감성점수                                                     -7
# 감성분석결과                                                   부정
# Name: 1299, dtype: object

# %%
box = []
contents_=df['내용'].iloc[:1000]
box.append(" ".join(contents_))

# %%
total=[]

drop_ = ['위해','이야기','해리','안나','선화','사라','한편','이제','과연','대한','점점','이자','다시']
for i in tqdm(okt.nouns(box[0])):
    if len(i)>1: 
        if i not in drop_ : total.append(i)
total
# Out:
# Exception ignored in: <function tqdm.__del__ at 0x000001B2C0F42A60>
# Traceback (most recent call last):
#   File "C:\Users\KDP-26-\anaconda3\envs\MY_PYTHON\lib\site-packages\tqdm\std.py", line 1145, in __del__
#     self.close()
#   File "C:\Users\KDP-26-\anaconda3\envs\MY_PYTHON\lib\site-packages\tqdm\std.py", line 1264, in close
#     if self.disable:
# AttributeError: 'tqdm' object has no attribute 'disable'
# 100%|███████████████████████████████████████████████████████████████████████| 70497/70497 [00:00<00:00, 1388124.79it/s]
# ['범죄',
#  '도시',
#  '대체',
#  '불가',
#  '괴물',
#  '형사',
#  '석도',
#  '서울',
#  '광수',
#  '발탁',
#  '베트남',
#  '납치',
#  '살해',
#  '검거',
#  '석도',
#  '마동석',
#  '팀원',
#  '살인',
#  '사건',
#  '조사',
#  '사건',
#  '조사',
#  '석도',
#  '신종',
#  '마약',
#  '사건',
#  '연루',
#  '수사',
#  '확대',
#  '마약',
#  '사건',
#  '배후',
#  '주성철',
#  '이준혁',
#  '계속',
#  '유통',
#  '일본',
#  '조직',
#  '리키',
#  '아오키',
#  '타카',
#  '한국',
#  '사건',
#  '규모',
#  '이유',
#  '제한',
#  '판도',
#  '엘리',
#  '멘탈',
#  '패키지',
#  '자막',
#  '더빙',
#  '부가',
#  '영상',
#  '터리',
#  '공기',
#  '원소',
#  '엘리',
#  '멘트',
#  '시티',
#  '재치',
#  '열정',
#  '앰버',
#  '감성',
#  '이드',
#  '우정',
#  '지금껏',
#  '모든',
#  '경험',
#  '웰컴',
#  '엘리',
#  '멘트',
#  '시티',
#  '공조',
#  '인터',
#  '공조',
#  '이즈',
#  '이번',
#  '삼각',
#  '공조',
#  '남한',
#  '글로벌',
#  '범죄',
#  '조직',
#  '잡기',
#  '공조',
#  '수사',
#  '투입',
#  '북한',
#  '형사',
#  '철령',
#  '현빈',
#  '수사',
#  '실수',
#  '사이버수사대',
#  '전출',
#  '남한',
#  '형사',
#  '진태',
#  '유해진',
#  '광수',
#  '복귀',
#  '모두',
#  '기피',
#  '철령',
#  '파트너',
#  '자청',
#  '공조',
#  '철령',
#  '진태',
#  '철령',
#  '재회',
#  '민영',
#  '임윤아',
#  '마음',
#  '불타',
#  '가운데',
#  '철령',
#  '진태',
#  '서로',
#  '의심',
#  '나름',
#  '공조',
#  '수사',
#  '범죄',
#  '조직',
#  '리더',
#  '진선규',
#  '은신',
#  '찰나',
#  '미국',
#  '소속',
#  '다니엘',
#  '남한',
#  '형사',
#  '엘리트',
#  '북한',
#  '형사',
#  '소속',
#  '해외',
#  '형사',
#  '각자',
#  '목적',
#  '공조',
#  '수사',
#  '시작',
#  '아바타',
#  '물의',
#  '부가',
#  '영상',
#  '제공',
#  '아바타',
#  '물의',
#  '판도라',
#  '행성',
#  '제이크',
#  '설리',
#  '네이티',
#  '가족',
#  '위협',
#  '여정',
#  '전투',
#  '상처',
#  '월드',
#  '와이드',
#  '역대',
#  '흥행',
#  '순위',
#  '기록',
#  '전편',
#  '아바타',
#  '제임스',
#  '카메론',
#  '감독',
#  '영화로',
#  '워싱턴',
#  '고니',
#  '위버',
#  '스티븐',
#  '케이트',
#  '윈슬렛',
#  '출연',
#  '랜도',
#  '프로듀싱',
#  '올빼미',
#  '맹인',
#  '침술',
#  '실력',
#  '경수',
#  '이형',
#  '재주',
#  '무렵',
#  '인질',
#  '소현세자',
#  '귀국',
#  '인조',
#  '아들',
#  '잠시',
#  '정체',
#  '불안감',
#  '어둠',
#  '경수',
#  '소현세자',
#  '죽음',
#  '목격',
#  '찰나',
#  '비밀',
#  '음모',
#  '목숨',
#  '위태',
#  '상황',
#  '아들',
#  '죽음',
#  '인조',
#  '불안감',
#  '광기',
#  '폭주',
#  '시작',
#  '세자',
#  '죽음',
#  '목격',
#  '경수',
#  '관련',
#  '인물',
#  '민낯',
#  '서서히',
#  '범죄',
#  '도시',
#  '가리봉동',
#  '소탕',
#  '작전',
#  '금천',
#  '강력반',
#  '베트남',
#  '도주',
#  '용의자',
#  '인도',
#  '오라',
#  '미션',
#  '괴물',
#  '형사',
#  '석도',
#  '마동석',
#  '전일',
#  '귀화',
#  '반장',
#  '현지',
#  '용의자',
#  '악행',
#  '해상',
#  '석도',
#  '금천',
#  '강력반',
#  '한국',
#  '베트남',
#  '역대',
#  '범죄',
#  '해상',
#  '본격',
#  '시작',
#  '국경',
#  '범죄',
#  '소탕',
#  '작전',
#  '에브리씽',
#  '에브리',
#  '웨어',
#  '원스',
#  '미국',
#  '이민',
#  '세탁소',
#  '운영',
#  '에블린',
#  '세무',
#  '당국',
#  '조사',
#  '남편',
#  '이혼',
#  '요구',
#  '혼란',
#  '순간',
#  '에블린',
#  '멀티버스',
#  '수천',
#  '수만',
#  '자신',
#  '세상',
#  '사실',
#  '모든',
#  '능력',
#  '위기',
#  '세상',
#  '가족',
#  '구해',
#  '운명',
#  '아바타',
#  '마스터링',
#  '미래',
#  '지구',
#  '에너지',
#  '고갈',
#  '문제',
#  '해결',
#  '행성',
#  '판도라',
#  '대체',
#  '자원',
#  '채굴',
#  '시작',
#  '판도라',
#  '독성',
#  '대기',
#  '자원',
#  '획득',
#  '어려움',
#  '인류',
#  '판도라',
#  '토착민',
#  '나비',
#  '외형',
#  '인간',
#  '의식',
#  '주입',
#  '원격',
#  '조종',
#  '생명체',
#  '아바타',
#  '탄생',
#  '프로그램',
#  '개발',
#  '하반신',
#  '마비',
#  '전직',
#  '해병대',
#  '제이크',
#  '설리',
#  '워딩튼',
#  '아바타',
#  '프로그램',
#  '참가',
#  '제안',
#  '판도라',
#  '위치',
#  '인간',
#  '주둔',
#  '기지',
#  '자신',
#  '아바타',
#  '통해',
#  '제이크',
#  '자원',
#  '채굴',
#  '나비',
#  '무리',
#  '침투',
#  '임무',
#  '부여',
#  '임무',
#  '수행',
#  '나비',
#  '전사',
#  '네이티',
#  '만난',
#  '제이크',
#  '그녀',
#  '모험',
#  '경험',
#  '네이티',
#  '사랑',
#  '나비',
#  '하나',
#  '간다',
#  '우주',
#  '운명',
#  '결정',
#  '대규모',
#  '전투',
#  '시작',
#  '제이크',
#  '최후',
#  '시험대',
#  '행성',
#  '판도라',
#  '지구',
#  '전쟁',
#  '모든',
#  '운명',
#  '제이크',
#  '선택',
#  '화이트',
#  '릴리',
#  '주인공',
#  '하루',
#  '아스카',
#  '시절',
#  '자신',
#  '도예',
#  '토키',
#  '야마구치',
#  '카오리',
#  '스승',
#  '모시',
#  '그녀',
#  '토키',
#  '주변',
#  '남성',
#  '관계',
#  '하루',
#  '성적',
#  '요구',
#  '자신',
#  '욕망',
#  '하루',
#  '그녀',
#  '진심',
#  '사랑',
#  '남성',
#  '사토',
#  '마치',
#  '우마',
#  '조수',
#  '그로',
#  '하루',
#  '점차',
#  '스승',
#  '욕망',
#  '시작',
#  '토키',
#  '하루',
#  '충격',
#  '명령',
#  '슈퍼',
#  '마리오',
#  '브라더스',
#  '패키지',
#  '자막',
#  '더빙',
#  '세계',
#  '열광',
#  '타임',
#  '슈퍼',
#  '어드벤처',
#  '등장',
#  '뉴욕',
#  '배관',
#  '형제',
#  '마리오',
#  '루이지',
#  '배수관',
#  '고장',
#  '위기',
#  '도시',
#  '미스터리',
#  '초록색',
#  '파이프',
#  '파이프',
#  '통해',
#  '세상',
#  '차원',
#  '이동',
#  '형제',
#  '마리오',
#  '리더십',
#  '피치',
#  '통치',
#  '버섯',
#  '왕국',
#  '도착',
#  '동생',
#  '루이지',
#  '빌런',
#  '쿠파',
#  '다크랜드',
#  '납치',
#  '마리오',
#  '동생',
#  '피치',
#  '키노피오',
#  '도움',
#  '쿠파',
#  '결심',
#  '슈퍼스타',
#  '세상',
#  '지배',
#  '위험',
#  '동생',
#  '세상',
#  '슈퍼',
#  '마리오',
#  '레벨',
#  '마리오',
#  '스펙',
#  '스테이지',
#  '시작',
#  '위기',
#  '최고',
#  '회의',
#  '트릴',
#  '방법',
#  '비로소',
#  '자유',
#  '희망',
#  '보지',
#  '빌런',
#  '그라몽',
#  '후작',
#  '세계',
#  '최강',
#  '연합',
#  '친구',
#  '위기',
#  '최후',
#  '반격',
#  '준비',
#  '레전드',
#  '액션',
#  '블록버스터',
#  '린다',
#  '랍스터',
#  '대미',
#  '문의',
#  '커플',
#  '메이킹',
#  '호텔',
#  '사랑',
#  '모두',
#  '유죄',
#  '유예',
#  '기간',
#  '동물',
#  '미래',
#  '모든',
#  '사람',
#  '서로',
#  '홀로',
#  '커플',
#  '메이킹',
#  '호텔',
#  '커플',
#  '교육',
#  '불구',
#  '얻지',
#  '사람',
#  '동물',
#  '이유',
#  '아내',
#  '호텔',
#  '데이비드',
#  '콜린',
#  '파렐',
#  '찾기',
#  '노력',
#  '커플',
#  '거부',
#  '혼자',
#  '선택',
#  '솔로',
#  '솔로',
#  '생활',
#  '유지',
#  '절대',
#  '규칙',
#  '바로',
#  '절대',
#  '사랑',
#  '아이러니',
#  '데이비드',
#  '사랑',
#  '허락',
#  '자신',
#  '근시',
#  '레이첼',
#  '와이즈',
#  '이름',
#  '도시',
#  '소년',
#  '타키',
#  '시골',
#  '소녀',
#  '미츠하',
#  '만난',
#  '사람',
#  '기적',
#  '사랑',
#  '이름',
#  '사람',
#  '사람',
#  '이름',
#  '남자',
#  '은밀',
#  '성인',
#  '클럽',
#  '쇼걸',
#  '나탈리',
#  '그녀',
#  '동경',
#  '바텐더',
#  '상드',
#  '클럽',
#  '해고',
#  '상드',
#  '나탈리',
#  '제안',
#  '그녀',
#  '동거',
#  '시작',
#  '나탈리',
#  '상드',
#  '성적',
#  '욕망',
#  '남자',
#  '성적',
#  '지배',
#  '하나',
#  '하나',
#  '간다',
#  '나탈리',
#  '쾌락',
#  '욕망',
#  '깨달',
#  '상드',
#  '그녀',
#  '자신',
#  '미모',
#  '이용',
#  '상류층',
#  '계획',
#  '화이트',
#  '칼라',
#  '남자',
#  '접근',
#  '절대',
#  '사랑',
#  '원칙',
#  '대기업',
#  '비서',
#  '취직',
#  '상드',
#  '나탈리',
#  '각자',
#  '유혹',
#  '대상',
#  '정해',
#  '본격',
#  '작업',
#  '상드',
#  '유혹',
#  '대상',
#  '회사',
#  '중역',
#  '중년',
#  '라크',
#  '사무실',
#  '은밀',
#  '섹스',
#  '회사',
#  '후계',
#  '크리스토퍼',
#  '문제',
#  '장면',
#  '크리스토퍼',
#  '상드',
#  '더욱',
#  '은밀',
#  '게임',
#  '제안',
#  '바람둥이',
#  '온갖',
#  '섹스',
#  '행위',
#  '크리스토퍼',
#  '게임',
#  '그녀',
#  '승리',
#  '블랙',
#  '아담',
#  '부가',
#  '영상',
#  '제공',
#  '기원전',
#  '가장',
#  '번성',
#  '고대',
#  '국가',
#  '현재',
#  '국제',
#  '군사',
#  '조직',
#  '인터',
#  '독재',
#  '국가',
#  '전락',
#  '다크',
#  '인터',
#  '피해',
#  '고대',
#  '유물',
#  '동안',
#  '블랙',
#  '아담',
#  '괴력',
#  '스피드',
#  '방탄',
#  '능력',
#  '자유자',
#  '재의',
#  '고공',
#  '비행',
#  '번개',
#  '능력',
#  '온몸',
#  '무기',
#  '블랙',
#  '아담',
#  '자신',
#  '인터',
#  '모조리',
#  '다크',
#  '국민',
#  '폭주',
#  '호크',
#  '닥터',
#  '페이트',
#  '아톰',
#  '스매셔',
#  '사이클론',
#  '구성',
#  '히어로',
#  '군단',
#  '저스티스',
#  '소사이어티',
#  '다크',
#  '세상',
#  '파괴',
#  '사람',
#  '문제',
#  '히어로',
#  '파라벨룸',
#  '전설',
#  '킬러',
#  '아누',
#  '리브',
#  '현상금',
#  '세계',
#  '모든',
#  '킬러',
#  '총구',
#  '국제',
#  '암살자',
#  '연맹',
#  '파문',
#  '조치',
#  '보호',
#  '시시각각',
#  '위험',
#  '직면',
#  '마지막',
#  '전쟁',
#  '소피아',
#  '할리',
#  '베리',
#  '출구',
#  '평화',
#  '전쟁',
#  '준비',
#  '하라',
#  '영웅',
#  '어머니',
#  '조마리아',
#  '나문희',
#  '가족',
#  '고향',
#  '대한제국',
#  '의병',
#  '대장',
#  '안중근',
#  '정성화',
#  '동지',
#  '손가락',
#  '단지',
#  '동맹',
#  '조국',
#  '독립',
#  '결의',
#  '안중근',
#  '조선',
#  '침략',
#  '원흉',
#  '이토',
#  '히로',
#  '처단',
#  '자결',
#  '피로',
#  '맹세',
#  '약속',
#  '블라디보스토크',
#  '안중근',
#  '동지',
#  '우덕순',
#  '조재윤',
#  '사수',
#  '도선',
#  '배정남',
#  '독립군',
#  '막내',
#  '유동',
#  '이현우',
#  '독립군',
#  '동지',
#  '진주',
#  '박진주',
#  '거사',
#  '준비',
#  '자신',
#  '정체',
#  '이토',
#  '히로',
#  '접근',
#  '적진',
#  '복판',
#  '목숨',
#  '정보',
#  '수집',
#  '독립군',
#  '정보원',
#  '김고은',
#  '이토',
#  '히로',
#  '미가',
#  '러시아',
#  '회담',
#  '하얼빈',
#  '일급',
#  '기밀',
#  '안중근',
#  '하얼빈역',
#  '도착',
#  '이토',
#  '히로',
#  '주저',
#  '방아쇠',
#  '현장',
#  '체포',
#  '전쟁',
#  '포로',
#  '살인',
#  '죄목',
#  '조선',
#  '일본',
#  '법정',
#  '누가',
#  '죄인',
#  '누가',
#  '영웅',
#  '비포',
#  '미드나잇',
#  '시작',
#  '사랑',
#  '비엔나',
#  '기차',
#  '파리',
#  '재회',
#  '제시',
#  '셀린느',
#  '지금',
#  '사람',
#  '사랑',
#  '시작',
#  '우리',
#  '사랑',
#  '시작',
#  '그리스',
#  '해변',
#  '마을',
#  '카르',
#  '밀리',
#  '매일',
#  '화해',
#  '지난',
#  '사랑',
#  '계속',
#  '간다',
#  '우리',
#  '사랑',
#  '비포',
#  '시리즈',
#  '마지막',
#  '가디언즈',
#  '오브',
#  '갤럭시',
#  '세트',
#  '가모라',
#  '슬픔',
#  '피터',
#  '위기',
#  '은하계',
#  '동료',
#  '한번',
#  '가디언즈',
#  '경우',
#  '마지막',
#  '미션',
#  '하몽',
#  '하몽',
#  '실비',
#  '로프',
#  '크루즈',
#  '고속도로',
#  '매춘',
#  '술집',
#  '운영',
#  '카르멘',
#  '칼리',
#  '조카',
#  '국내',
#  '번역',
#  '조카',
#  '실제',
#  '설정',
#  '어머니',
#  '팬티',
#  '회사',
#  '공장',
#  '관능',
#  '처녀',
#  '실비',
#  '팬티',
#  '공장',
#  '사장',
#  '아들',
#  '호세',
#  '조디',
#  '연인',
#  '사이',
#  '호세',
#  '어머니',
#  '콘치',
#  '스테파니',
#  '샌드렐리',
#  '반대',
#  '사람',
#  '창녀',
#  '조카',
#  '신분',
#  '이유',
#  '호세',
#  '아버지',
#  '마뉴',
#  '후안',
#  '디에고',
#  '카르멘',
#  '불륜',
#  '관계',
#  '사실',
#  '때문',
#  '호세',
#  '비아',
#  '결혼',
#  '승락',
#  '하자',
#  '사람',
#  '사이',
#  '작심',
#  '콘치',
#  '건조',
#  '공장',
#  '투우사',
#  '지망',
#  '라울',
#  '하비에르',
#  '바르뎀',
#  '고용',
#  '비아',
#  '유혹',
#  '주문',
#  '과정',
#  '라울',
#  '육체',
#  '콘치',
#  '라울',
#  '불륜',
#  '행각',
#  '벌이',
#  '라울',
#  '접근',
#  '마음',
#  '시작',
#  '실비',
#  '때문',
#  '번뇌',
#  '호세',
#  '카르멘',
#  '육체',
#  '관계',
#  '비아',
#  '관계',
#  '라울',
#  '콘치',
#  '정사',
#  '장면',
#  ...]

# %%
# 빈도분석 라이브러리
from collections import Counter
result=Counter(total)

dic={}
for a in tqdm(result.most_common(100)):
    dic[a[0]]=a[1]
dic
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<?, ?it/s]
# {'자신': 544,
#  '시작': 483,
#  '그녀': 458,
#  '사랑': 428,
#  '사람': 351,
#  '친구': 228,
#  '세상': 205,
#  '사건': 204,
#  '세계': 201,
#  '모든': 191,
#  '가족': 186,
#  '남자': 185,
#  '모두': 149,
#  '마음': 141,
#  '아들': 140,
#  '시간': 139,
#  '서로': 137,
#  '아이': 135,
#  '엄마': 134,
#  '다른': 129,
#  '여자': 129,
#  '사이': 125,
#  '인간': 123,
#  '최고': 123,
#  '위기': 121,
#  '비밀': 120,
#  '인생': 120,
#  '가장': 117,
#  '아내': 111,
#  '하나': 106,
#  '사실': 103,
#  '순간': 100,
#  '운명': 97,
#  '경찰': 97,
#  '발견': 97,
#  '아버지': 96,
#  '학교': 96,
#  '전쟁': 93,
#  '남편': 91,
#  '마지막': 91,
#  '모습': 90,
#  '조직': 89,
#  '영화': 88,
#  '기억': 87,
#  '소녀': 86,
#  '죽음': 84,
#  '소년': 84,
#  '지구': 83,
#  '생활': 79,
#  '존재': 79,
#  '통해': 77,
#  '도움': 76,
#  '이름': 76,
#  '마을': 76,
#  '목숨': 73,
#  '상황': 73,
#  '만난': 73,
#  '우리': 73,
#  '영상': 72,
#  '과거': 72,
#  '작전': 71,
#  '때문': 71,
#  '마법': 71,
#  '도시': 70,
#  '모험': 70,
#  '처음': 70,
#  '관계': 69,
#  '간다': 68,
#  '이후': 67,
#  '여행': 67,
#  '부가': 65,
#  '정체': 65,
#  '가지': 65,
#  '현실': 64,
#  '여인': 64,
#  '누구': 63,
#  '사고': 63,
#  '능력': 62,
#  '생각': 62,
#  '아빠': 62,
#  '바로': 61,
#  '동료': 61,
#  '하루': 60,
#  '결혼': 60,
#  '살인': 59,
#  '감독': 59,
#  '일상': 59,
#  '상처': 58,
#  '결심': 58,
#  '게임': 58,
#  '마침내': 58,
#  '더빙': 55,
#  '제안': 55,
#  '공격': 55,
#  '위협': 54,
#  '시절': 54,
#  '계획': 54,
#  '복수': 54,
#  '탈출': 54,
#  '우주': 53}

# %% [markdown]
# # 워드클라우드

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

wc=WordCloud(background_color='white', 
             font_path='../PYHTON/crawling/BMDOHYEON_ttf.ttf')
cloud=wc.generate_from_frequencies(dic)
plt.axis('off')
plt.imshow(cloud)

# %%
def word_cloud(name):
    idx = df[df['제목']==name_].index[0]
    text = df['내용'][idx]

    total=[]
    
    # 의미없는 단어 제외
    drop_ = ['위해','이야기','해리','안나','선화','사라','한편','이제','과연','대한','점점','이자','다시']
    okt = Okt()
    for i in tqdm(okt.nouns(text)):
        # 한자리 제외
        if len(i)>1: 
            if i not in drop_ : total.append(i)

    result=Counter(total)

    dic={}
    # 100개 까지만 표시
    for a in tqdm(result.most_common(100)):
        dic[a[0]]=a[1]

    wc=WordCloud(background_color='white', 
                 font_path='BMDOHYEON_ttf.ttf')
    cloud=wc.generate_from_frequencies(dic)
    plt.axis('off')
    plt.imshow(cloud)

# %%
name = '범죄도시3'
word_cloud(name)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 65/65 [00:00<00:00, 60732.85it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:00<?, ?it/s]
